# %% [markdown]
# # Introduction to Pandas
#
# Pandas is a package built on top of numpy which incorporates many additional features which make it more convenient for data analysis. One main addition is the inclusion of row and column labels, which make pandas function much like spreadsheet software. It also includes tools for much more complex computations than regular numpy allows

# %%
import pandas as pd
import numpy as np
# by default, pandas only shows the beginning and end of a large dataframe
# You can choose how many rows and columns to show.
# If you want to see all of the rows, set the respective value to None
pd.options.display.max_rows = 100 
pd.options.display.max_columns = 50

# %% [markdown]
# ## Importing data
# There are a lot of built-in functions for importing data to pandas, for example, from files, database, and web sources. For a full list of the supported methods, see [the documentation on pandas](https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html).
#
# In this example, we're going to load data formatted as a csv from a website URL. In particular, it is a direct link to a file hosted in our course github repository.
#
# The data we're loading is a simplified pokedex which includes the number, name, base stats, types, abilities, and colors of each pokemon. We'll be using this data to explore the functionality of pandas.
#
# The primary class of pandas is the DataFrame, which functions like a spreadsheet (like in excel). It allows for named rows and columns. Data types between two different columns can vary, but entries within the same column should have the same type.

# %%
# URL for data hosted online
pokedex_url = 'https://raw.githubusercontent.com/bwsi-remote-sensing-2023/01-Intro-to-python/master/pokedex.csv' 
pokedex_df = pd.read_csv(pokedex_url, index_col='Index') # create a dataframe from a csv, set the column titled "Index" as the row labels

# %%
# in our case, the cloned repository includes the pokedex file in the folder, 
# so we could equivalently use the filename instead of a URL
pokedex_df = pd.read_csv('pokedex.csv', index_col='Index')

# %%
# We'll do some cleanup to deal with empty values
pokedex_df = pokedex_df.fillna('') # fill in the NaN values with empty string 
pokedex_df # prints out the dataframe
# Out:
#           Pokemon   HP  Atk  Def  SpAtk  SpDef  Speed  Total    Type I  \
# Index
# 1.0     Bulbasaur   45   49   49     65     65     45    318     Grass
# 2.0       Ivysaur   60   62   63     80     80     60    405     Grass
# 3.0      Venusaur   80   82   83    100    100     80    525     Grass
# 4.0    Charmander   39   52   43     60     50     65    309      Fire
# 5.0    Charmeleon   58   64   58     80     65     80    405      Fire
# ...           ...  ...  ...  ...    ...    ...    ...    ...       ...
# 798.0     Kartana   59  181  131     59     31    109    570     Grass
# 799.0    Guzzlord  223  101   53     97     53     43    570      Dark
# 800.0    Necrozma   97  107  101    127     89     79    600   Psychic
# 801.0    Magearna   80   95  115    130    115     65    600     Steel
# 802.0   Marshadow   90  125   80     90     90    125    600  Fighting
#
#       Type II    Ability I Ability II Hidden Ability  Color
# Index
# 1.0    Poison     Overgrow               Chlorophyll  Green
# 2.0    Poison     Overgrow               Chlorophyll  Green
# 3.0    Poison     Overgrow               Chlorophyll  Green
# 4.0                  Blaze               Solar Power    Red
# 5.0                  Blaze               Solar Power    Red
# ...       ...          ...        ...            ...    ...
# 798.0   Steel  Beast Boost                            White
# 799.0  Dragon  Beast Boost                            Black
# 800.0          Prism Armor                            Black
# 801.0   Fairy   Soul-Heart                             Gray
# 802.0   Ghost   Technician                             Gray
#
# [820 rows x 14 columns]

# %% [markdown]
# ## Indexing
# Like numpy, you can index a dataframe to select elements or subsets of entries. There are a number of ways to index pandas dataframes. The two following methods are recommended:
# `.loc[]` and `.iloc[]`

# %% [markdown]
# ### .loc[ ] name-based indexing
# The first way, using `.loc[a,b]` indexes based on the __values__ of the row index and column names. This allows us to get entries where the row index value equals `a` and the column name equals `b`.

# %%
# Get the entry for index value 745.1 - Lycanroc (midnight)
pokedex_df.loc[745.1]
# Out:
# Pokemon           Lycanroc (midnight)
# HP                                 85
# Atk                               115
# Def                                75
# SpAtk                              55
# SpDef                              75
# Speed                              82
# Total                             487
# Type I                           Rock
# Type II
# Ability I                    Keen Eye
# Ability II              Vital Spirit
# Hidden Ability               No Guard
# Color                           Brown
# Name: 745.1, dtype: object

# %%
# You can get specific column values for a single entry
pokedex_df.loc[250,['Pokemon','Type I','Type II']]
# Out:
# Pokemon    Swinub
# Type I        Ice
# Type II    Ground
# Name: 250.0, dtype: object

# %%
# you can use the : notation to slice multiple rows and columns
pokedex_df.loc[690:700,'Pokemon':'Total']
# Out:
#           Pokemon   HP  Atk  Def  SpAtk  SpDef  Speed  Total
# Index
# 690.0      Skrelp   50   60   60     60     60     30    320
# 691.0    Dragalge   65   75   90     97    123     44    494
# 692.0   Clauncher   50   53   62     58     63     44    330
# 693.0   Clawitzer   71   73   88    120     89     59    500
# 694.0  Helioptile   44   38   33     61     43     70    289
# 695.0   Heliolisk   62   55   52    109     94    109    481
# 696.0      Tyrunt   58   89   77     45     45     48    362
# 697.0   Tyrantrum   82  121  119     69     59     71    521
# 698.0      Amaura   77   59   50     67     63     46    362
# 699.0     Aurorus  123   77   72     99     92     58    521
# 700.0     Sylveon   95   65   65    110    130     60    525

# %%
# Similarly to numpy, you can use the : notation without indices on a side to mean "from beginning" or "to end"
pokedex_df.loc[:10,"Ability I":]
# Out:
#          Ability I Ability II Hidden Ability  Color
# Index
# 1.0       Overgrow               Chlorophyll  Green
# 2.0       Overgrow               Chlorophyll  Green
# 3.0       Overgrow               Chlorophyll  Green
# 4.0          Blaze               Solar Power    Red
# 5.0          Blaze               Solar Power    Red
# 6.0          Blaze               Solar Power    Red
# 7.0        Torrent                 Rain Dish   Blue
# 8.0        Torrent                 Rain Dish   Blue
# 9.0        Torrent                 Rain Dish   Blue
# 10.0   Shield Dust                  Run Away  Green

# %%
# and : by itself gives all of the entries in that dimension
pokedex_df.loc[:,'Pokemon'].head(10) #just return top 10 entries
# Out:
# Index
# 1.0      Bulbasaur
# 2.0        Ivysaur
# 3.0       Venusaur
# 4.0     Charmander
# 5.0     Charmeleon
# 6.0      Charizard
# 7.0       Squirtle
# 8.0      Wartortle
# 9.0      Blastoise
# 10.0      Caterpie
# Name: Pokemon, dtype: object

# %% [markdown]
# ### .iloc[ ] integer indexing
#
# The second way, using `.iloc[i,j]` uses the numpy-style integer indices to get a value. In this case, iloc takes integer values from 0 to the number of entries in that dimension.
#
# Like numpy, `.iloc[i,j]` gives the entry at the $i^{th}$ row and $j^{th}$ column.

# %%
pokedex_df.iloc[100] # gets 101st row (recall python counts from 0)
# Out:
# Pokemon            Electrode
# HP                        60
# Atk                       50
# Def                       70
# SpAtk                     80
# SpDef                     80
# Speed                    140
# Total                    480
# Type I              Electric
# Type II
# Ability I         Soundproof
# Ability II            Static
# Hidden Ability     Aftermath
# Color                    Red
# Name: 110.0, dtype: object

# %%
# The : style indexing also works for iloc
pokedex_df.iloc[25:30, 0:8]
# Out:
#          Pokemon  HP  Atk  Def  SpAtk  SpDef  Speed  Total
# Index
# 27.0      Raichu  60   90   55     90     80    100    475
# 28.0   Sandshrew  50   75   85     20     30     40    300
# 29.0   Sandslash  75  100  110     45     55     65    450
# 30.0    Nidoran♀  55   47   52     40     40     41    275
# 31.0    Nidorina  70   62   67     55     55     56    365

# %% [markdown]
# ## Changing index column
# You can change the index column of the dataframe with `.set_index()` or reset it to default numerical indexing with `.reset_index()`.
#
# Note however, that these operations create a __copy__ of the original dataframe, and do not change the dataframe "in place" (i.e. doesn't change the original object)

# %%
# reset index to be default numerical index
reindexed_pokedex = pokedex_df.reset_index()
reindexed_pokedex.head()
# Out:
#    Index     Pokemon  HP  Atk  Def  SpAtk  SpDef  Speed  Total Type I Type II  \
# 0    1.0   Bulbasaur  45   49   49     65     65     45    318  Grass  Poison
# 1    2.0     Ivysaur  60   62   63     80     80     60    405  Grass  Poison
# 2    3.0    Venusaur  80   82   83    100    100     80    525  Grass  Poison
# 3    4.0  Charmander  39   52   43     60     50     65    309   Fire
# 4    5.0  Charmeleon  58   64   58     80     65     80    405   Fire
#
#   Ability I Ability II Hidden Ability  Color
# 0  Overgrow               Chlorophyll  Green
# 1  Overgrow               Chlorophyll  Green
# 2  Overgrow               Chlorophyll  Green
# 3     Blaze               Solar Power    Red
# 4     Blaze               Solar Power    Red

# %%
# Change the index to the Pokemon name column
pokedex_indexed_by_name = pokedex_df.reset_index().set_index('Pokemon')
pokedex_indexed_by_name
# Out:
#             Index   HP  Atk  Def  SpAtk  SpDef  Speed  Total    Type I  \
# Pokemon
# Bulbasaur     1.0   45   49   49     65     65     45    318     Grass
# Ivysaur       2.0   60   62   63     80     80     60    405     Grass
# Venusaur      3.0   80   82   83    100    100     80    525     Grass
# Charmander    4.0   39   52   43     60     50     65    309      Fire
# Charmeleon    5.0   58   64   58     80     65     80    405      Fire
# ...           ...  ...  ...  ...    ...    ...    ...    ...       ...
# Kartana     798.0   59  181  131     59     31    109    570     Grass
# Guzzlord    799.0  223  101   53     97     53     43    570      Dark
# Necrozma    800.0   97  107  101    127     89     79    600   Psychic
# Magearna    801.0   80   95  115    130    115     65    600     Steel
# Marshadow   802.0   90  125   80     90     90    125    600  Fighting
#
#            Type II    Ability I Ability II Hidden Ability  Color
# Pokemon
# Bulbasaur   Poison     Overgrow               Chlorophyll  Green
# Ivysaur     Poison     Overgrow               Chlorophyll  Green
# Venusaur    Poison     Overgrow               Chlorophyll  Green
# Charmander                Blaze               Solar Power    Red
# Charmeleon                Blaze               Solar Power    Red
# ...            ...          ...        ...            ...    ...
# Kartana      Steel  Beast Boost                            White
# Guzzlord    Dragon  Beast Boost                            Black
# Necrozma            Prism Armor                            Black
# Magearna     Fairy   Soul-Heart                             Gray
# Marshadow    Ghost   Technician                             Gray
#
# [820 rows x 14 columns]

# %%
# note that the original dataframe was not affected
pokedex_df
# Out:
#           Pokemon   HP  Atk  Def  SpAtk  SpDef  Speed  Total    Type I  \
# Index
# 1.0     Bulbasaur   45   49   49     65     65     45    318     Grass
# 2.0       Ivysaur   60   62   63     80     80     60    405     Grass
# 3.0      Venusaur   80   82   83    100    100     80    525     Grass
# 4.0    Charmander   39   52   43     60     50     65    309      Fire
# 5.0    Charmeleon   58   64   58     80     65     80    405      Fire
# ...           ...  ...  ...  ...    ...    ...    ...    ...       ...
# 798.0     Kartana   59  181  131     59     31    109    570     Grass
# 799.0    Guzzlord  223  101   53     97     53     43    570      Dark
# 800.0    Necrozma   97  107  101    127     89     79    600   Psychic
# 801.0    Magearna   80   95  115    130    115     65    600     Steel
# 802.0   Marshadow   90  125   80     90     90    125    600  Fighting
#
#       Type II    Ability I Ability II Hidden Ability  Color
# Index
# 1.0    Poison     Overgrow               Chlorophyll  Green
# 2.0    Poison     Overgrow               Chlorophyll  Green
# 3.0    Poison     Overgrow               Chlorophyll  Green
# 4.0                  Blaze               Solar Power    Red
# 5.0                  Blaze               Solar Power    Red
# ...       ...          ...        ...            ...    ...
# 798.0   Steel  Beast Boost                            White
# 799.0  Dragon  Beast Boost                            Black
# 800.0          Prism Armor                            Black
# 801.0   Fairy   Soul-Heart                             Gray
# 802.0   Ghost   Technician                             Gray
#
# [820 rows x 14 columns]

# %% [markdown]
# ## Logical indexing
# You can test conditionals on a column, for example, testing if the value of the column is greater than a value. What's returned is a boolean column of the same size, with a value of `True` wherever it is true, and `False` otherwise. (This can similarly be done in numpy).

# %%
pokedex_df['Total'] > 520
# Out:
# Index
# 1.0      False
# 2.0      False
# 3.0       True
# 4.0      False
# 5.0      False
#          ...
# 798.0     True
# 799.0     True
# 800.0     True
# 801.0     True
# 802.0     True
# Name: Total, Length: 820, dtype: bool

# %% [markdown]
# If you take that boolean column and use it to index the dataframe, you can get all of the entries that satisfy that condition.

# %%
pokedex_df.loc[pokedex_df['Total']>=520] # all of the pokemon with total base stats greater than 500
# Out:
#          Pokemon   HP  Atk  Def  SpAtk  SpDef  Speed  Total    Type I Type II  \
# Index
# 3.0     Venusaur   80   82   83    100    100     80    525     Grass  Poison
# 6.0    Charizard   78   84   78    109     85    100    534      Fire  Flying
# 9.0    Blastoise   79   83  100     85    105     78    530     Water
# 64.0    Arcanine   90  110   80    100     80     95    555      Fire
# 99.0    Cloyster   50   90  180     85     45     70    520     Water     Ice
# ...          ...  ...  ...  ...    ...    ...    ...    ...       ...     ...
# 798.0    Kartana   59  181  131     59     31    109    570     Grass   Steel
# 799.0   Guzzlord  223  101   53     97     53     43    570      Dark  Dragon
# 800.0   Necrozma   97  107  101    127     89     79    600   Psychic
# 801.0   Magearna   80   95  115    130    115     65    600     Steel   Fairy
# 802.0  Marshadow   90  125   80     90     90    125    600  Fighting   Ghost
#
#          Ability I  Ability II Hidden Ability   Color
# Index
# 3.0       Overgrow                Chlorophyll   Green
# 6.0          Blaze                Solar Power     Red
# 9.0        Torrent                  Rain Dish    Blue
# 64.0    Intimidate  Flash Fire      Justified   Brown
# 99.0   Shell Armor  Skill Link       Overcoat  Purple
# ...            ...         ...            ...     ...
# 798.0  Beast Boost                              White
# 799.0  Beast Boost                              Black
# 800.0  Prism Armor                              Black
# 801.0   Soul-Heart                               Gray
# 802.0   Technician                               Gray
#
# [163 rows x 14 columns]

# %%
# Get all of the pokemon of a given color
pokedex_df.loc[pokedex_df['Color']=='Black']
# Out:
#             Pokemon   HP  Atk  Def  SpAtk  SpDef  Speed  Total    Type I  \
# Index
# 174.0       Snorlax  160  110   65     65    110     30    540    Normal
# 162.0       Umbreon   95   65  110     60    130     65    525      Dark
# 226.0       Murkrow   60   85   42     85     42     91    405      Dark
# 230.0         Unown   48   72   48     72     48     48    336   Psychic
# 244.0       Sneasel   55   95   55     35     75    115    430      Dark
# 260.0      Houndour   45   60   30     80     50     65    330      Dark
# 261.0      Houndoom   75   90   50    110     80     95    500      Dark
# 328.0        Mawile   50   85   85     55     55     50    380     Steel
# 352.0        Spoink   60   25   35     70     80     60    330   Psychic
# 363.0       Seviper   73  100   60    100     60     65    458    Poison
# 371.0       Claydol   60   70  105     70    120     75    500    Ground
# 380.0       Shuppet   44   75   35     63     33     45    295     Ghost
# 381.0       Banette   64  115   65     83     63     65    455     Ghost
# 382.0       Duskull   20   40   90     30     90     25    295     Ghost
# 383.0      Dusclops   40   70  130     60    130     25    455     Ghost
# 227.0     Honchkrow  100  125   52    105     52     71    505      Dark
# 461.0        Chatot   76   65   45     92     42     91    411    Normal
# 173.0      Munchlax  135   85   40     40     85      5    390    Normal
# 245.0       Weavile   70  120   65     45     85    125    510      Dark
# 384.0      Dusknoir   45  100  135     65    135     45    525     Ghost
# 487.0      Giratina  150  100  120    100    120     90    680     Ghost
# 487.1  Giratina (O)  150  120  100    120    100     90    680     Ghost
# 491.0       Darkrai   70   90   90    135     90    125    600      Dark
# 522.0       Blitzle   45   60   32     50     32     76    295  Electric
# 523.0     Zebstrika   75  100   63     80     63    116    497  Electric
# 561.0      Sigilyph   72   58   80    103     80     97    490   Psychic
# 562.0        Yamask   38   30   85     55     65     30    303     Ghost
# 608.0       Lampent   60   40   60     95     60     55    370     Ghost
# 609.0    Chandelure   60   55   90    145     90     80    520     Ghost
# 644.0        Zekrom  100  150  120    120    100     90    680    Dragon
# 664.0    Scatterbug   38   35   40     27     25     35    200       Bug
# 665.0        Spewpa   45   22   60     27     30     29    213       Bug
# 666.0      Vivillon   80   52   50     90     50     89    411       Bug
# 731.0       Pikipek   35   75   30     30     30     65    265    Normal
# 732.0      Trumbeak   55   85   50     40     50     75    355    Normal
# 733.0     Toucannon   80  120   75     75     75     60    485    Normal
# 757.0      Salandit   48   44   40     71     40     77    320    Poison
# 758.0      Salazzle   68   64   60    111     60    117    480    Poison
# 771.0     Pyukumuku   55   60  130     30    130      5    410     Water
# 796.0     Xurkitree   83   89   71    173     71     83    570  Electric
# 799.0      Guzzlord  223  101   53     97     53     43    570      Dark
# 800.0      Necrozma   97  107  101    127     89     79    600   Psychic
#
#         Type II     Ability I     Ability II Hidden Ability  Color
# Index
# 174.0                Immunity      Thick Fat       Gluttony  Black
# 162.0             Synchronize                   Inner Focus  Black
# 226.0    Flying      Insomnia     Super Luck      Prankster  Black
# 230.0                Levitate                                Black
# 244.0       Ice   Inner Focus       Keen Eye     Pickpocket  Black
# 260.0      Fire    Early Bird     Flash Fire        Unnerve  Black
# 261.0      Fire    Early Bird     Flash Fire        Unnerve  Black
# 328.0     Fairy  Hyper Cutter     Intimidate    Sheer Force  Black
# 352.0               Thick Fat      Own Tempo       Gluttony  Black
# 363.0               Shed Skin                   Infiltrator  Black
# 371.0   Psychic      Levitate                                Black
# 380.0                Insomnia          Frisk    Cursed Body  Black
# 381.0                Insomnia          Frisk    Cursed Body  Black
# 382.0                Levitate                                Black
# 383.0                Pressure                                Black
# 227.0    Flying      Insomnia     Super Luck          Moxie  Black
# 461.0    Flying      Keen Eye   Tangled Feet      Big Pecks  Black
# 173.0                  Pickup      Thick Fat       Gluttony  Black
# 245.0       Ice      Pressure                    Pickpocket  Black
# 384.0                Pressure                                Black
# 487.0    Dragon      Pressure                     Telepathy  Black
# 487.1    Dragon      Levitate                                Black
# 491.0              Bad Dreams                                Black
# 522.0            Lightningrod    Motor Drive     Sap Sipper  Black
# 523.0            Lightningrod    Motor Drive     Sap Sipper  Black
# 561.0    Flying   Wonder Skin    Magic Guard    Tinted Lens  Black
# 562.0                   Mummy                                Black
# 608.0      Fire    Flash Fire     Flame Body     Shadow Tag  Black
# 609.0      Fire    Flash Fire     Flame Body     Shadow Tag  Black
# 644.0  Electric      Teravolt                                Black
# 664.0             Shield Dust  Compound Eyes   Friend Guard  Black
# 665.0               Shed Skin                  Friend Guard  Black
# 666.0    Flying   Shield Dust  Compound Eyes   Friend Guard  Black
# 731.0    Flying     Keen Eye     Skill Link          Pickup  Black
# 732.0    Flying     Keen Eye     Skill Link          Pickup  Black
# 733.0    Flying     Keen Eye     Skill Link     Sheer Force  Black
# 757.0      Fire    Corrosion       Oblivious      Oblivious  Black
# 758.0      Fire    Corrosion       Oblivious      Oblivious  Black
# 771.0             Innards Out        Unaware        Unaware  Black
# 796.0             Beast Boost                                Black
# 799.0    Dragon   Beast Boost                                Black
# 800.0             Prism Armor                                Black

# %% [markdown]
# ### Compound boolean queries
# You can use boolean operations (OR, AND, NOT) to combine conditions
#
# We will look for pokemon with specific types to demonstrate compound queries

# %% [markdown]
# ### OR queries
# In the following example, we query for all pokemon who have at least part "Dragon" typing.
#
# The vertical line | represents the element-wise "OR" operation. "OR" operations require either or both statements on either side of the operation to be true.
#
# Thus, the below query
#
# ```query = (pokedex_df['Type I']=='Dragon') | (pokedex_df['Type II']=='Dragon')```
#
# asks, for each row, if 'Type I' is equal to "Dragon" OR 'Type II' is equal to "Dragon"

# %%
query = (pokedex_df['Type I']=='Dragon') | (pokedex_df['Type II']=='Dragon')
pokedex_df.loc[query] # Get all of the entries corresponding to the above query
# Out:
# 356.0    Dragon      Levitate                                Green
# 357.0    Dragon      Levitate                                Green
# 361.0    Flying  Natural Cure                   Cloud Nine    Blue
# 400.0               Rock Head                  Sheer Force    Blue
# 401.0               Rock Head                     Overcoat   White
# 402.0    Flying    Intimidate                        Moxie    Blue
# 409.0   Psychic      Levitate                                  Red
# 410.0   Psychic      Levitate                                 Blue
# 413.0    Flying      Air Lock                                Green
# 463.0    Ground     Sand Veil                   Rough Skin    Blue
# 464.0    Ground     Sand Veil                   Rough Skin    Blue
# 465.0    Ground     Sand Veil                   Rough Skin    Blue
# 483.0    Dragon      Pressure                    Telepathy   White
# 484.0    Dragon      Pressure                    Telepathy  Purple
# 487.0    Dragon      Pressure                    Telepathy   Black
# 487.1    Dragon      Levitate                                Black
# 610.0                 Rivalry  Mold Breaker        Unnerve   Green
# 611.0                 Rivalry  Mold Breaker        Unnerve   Green
# 612.0                 Rivalry  Mold Breaker        Unnerve  Yellow
# 621.0              Rough Skin   Sheer Force   Mold Breaker     Red
# 633.0    Dragon        Hustle                                 Blue
# 634.0    Dragon        Hustle                                 Blue
# 635.0    Dragon      Levitate                                 Blue
# 643.0      Fire    Turboblaze                                White
# 644.0  Electric      Teravolt                                Black
# 646.0       Ice      Pressure                                 Gray
# 691.0    Dragon  Poison Point  Poison Touch   Adaptability   Brown
# 696.0    Dragon    Strong Jaw                       Sturdy   Brown
# 697.0    Dragon    Strong Jaw                       Sturdy     Red
# 704.0              Sap Sipper     Hydration          Gooey  Purple
# 705.0              Sap Sipper     Hydration          Gooey  Purple
# 706.0              Sap Sipper     Hydration          Gooey  Purple
# 714.0    Dragon         Frisk   Infiltrator      Telepathy  Purple
# 715.0    Dragon         Frisk   Infiltrator      Telepathy  Purple
# 718.0    Ground    Aura Break                                Green
# 776.0    Dragon   Shell Armor                                  Red
# 780.0    Dragon      Berserk    Sap Sipper      Cloud Nine   White
# 782.0            Bulletproof    Soundproof        Overcoat    Gray
# 783.0  Fighting  Bulletproof    Soundproof        Overcoat    Gray
# 784.0  Fighting  Bulletproof    Soundproof        Overcoat    Gray
# 799.0    Dragon   Beast Boost                                Black

# %%
(pokedex_df['Type I']=='Dragon').all()
# Out:
# False

# %% [markdown]
# ### AND queries
# The ampersand `&` character represents the element-wise boolean operation "AND". In order for an "AND" statement to be true, both conditions on either side of the operation must be true.
#
# We can combine boolean operations to construct complex queries: for example, getting all pokemon who are both Dragon and Flying types. The query below looks for pokemon who are EITHER (Primary Type "Flying" AND Secondary Type "Dragon") OR (Primary Type "Dragon" AND Secondary Type "Flying")
#
# Note that parentheses should be used to group operations so that the order of operations is clear

# %% [markdown]
# ### NOT queries
# There are two ways to do negation. Consider the following query for selecting all pokemon who are Fire type, but not Flying
#
# ```
# query = ((pokedex_df['Type I']=='Fire') & ~(pokedex_df['Type II']=='Flying'))\
#         | ((pokedex_df['Type I']!='Flying') & (pokedex_df['Type II']=='Fire'))
# ```
#
# The first way to do negation is with the tilde ~ symbol, which negates the subsequent boolean statement:
# We use this in `~(pokedex_df['Type II']=='Flying')`.
# The parentheses determine order of operations. First we find all entries where their secondary type is "Flying"
# Then the tilde in front negates that statement, flipping all True values to False, and vice versa
#
# The second way to do negation is using the != notation, which represents "not equal to"
# We use this in `(pokedex_df['Type I']!='Flying')`
# This finds all entries where their primary type is not equal to "Flying"

# %%
query = ((pokedex_df['Type I']=='Fire') & ~(pokedex_df['Type II']=='Flying'))\
        | ((pokedex_df['Type I']!='Flying') & (pokedex_df['Type II']=='Fire'))

pokedex_df.loc[query]
# Out:
#               Pokemon   HP  Atk  Def  SpAtk  SpDef  Speed  Total    Type I  \
# Index
# 4.0        Charmander   39   52   43     60     50     65    309      Fire
# 5.0        Charmeleon   58   64   58     80     65     80    405      Fire
# 39.0           Vulpix   38   41   40     50     65     65    299      Fire
# 40.0        Ninetales   73   76   75     81    100    100    505      Fire
# 63.0        Growlithe   55   70   45     70     50     60    350      Fire
# 64.0         Arcanine   90  110   80    100     80     95    555      Fire
# 83.0           Ponyta   50   85   55     65     65     90    410      Fire
# 84.0         Rapidash   65  100   70     80     80    105    500      Fire
# 149.0          Magmar   65   95   57    100     85     93    495      Fire
# 160.0         Flareon   65  130   60     95    110     65    525      Fire
# 186.0       Cyndaquil   39   52   43     60     50     65    309      Fire
# 187.0         Quilava   58   64   58     80     65     80    405      Fire
# 188.0      Typhlosion   78   84   78    109     85    100    534      Fire
# 248.0          Slugma   40   40   40     70     40     20    250      Fire
# 249.0        Magcargo   50   50  120     80     80     30    410      Fire
# 260.0        Houndour   45   60   30     80     50     65    330      Dark
# 261.0        Houndoom   75   90   50    110     80     95    500      Dark
# 148.0           Magby   45   75   37     70     55     83    365      Fire
# 268.0           Entei  115  115   85     90     75    100    580      Fire
# 279.0         Torchic   45   60   40     70     50     45    310      Fire
# 280.0       Combusken   60   85   60     85     60     55    405      Fire
# 281.0        Blaziken   80  120   70    110     70     80    530      Fire
# 349.0           Numel   60   60   40     65     45     35    305      Fire
# 350.0        Camerupt   70  100   70    105     75     40    460      Fire
# 351.0         Torkoal   70   85  140     85     70     20    470      Fire
# 419.0        Chimchar   44   58   44     58     44     61    309      Fire
# 420.0        Monferno   64   78   52     78     52     81    405      Fire
# 421.0       Infernape   76  104   71    104     71    108    534      Fire
# 150.0       Magmortar   75   95   67    125     95     83    540      Fire
# 479.1    Rotom (Heat)   50   65  107    105    107     86    520  Electric
# 485.0         Heatran   91   90  106    130    106     77    600      Fire
# 494.0         Victini  100  100  100    100    100    100    600   Psychic
# 498.0           Tepig   65   63   45     45     45     45    308      Fire
# 499.0         Pignite   90   93   55     70     55     55    418      Fire
# 500.0          Emboar  110  123   65    100     65     65    528      Fire
# 513.0         Pansear   50   53   48     53     48     64    316      Fire
# 514.0        Simisear   75   98   63     98     63    101    498      Fire
# 554.0        Darumaka   70   90   45     15     45     50    315      Fire
# 555.0      Darmanitan  105  140   55     30     55     95    480      Fire
# 555.1  Darmanitan (Z)  105   30  105    140    105     55    540      Fire
# 607.0         Litwick   50   30   55     65     55     20    275     Ghost
# 555.1   Psychic                                 Zen Mode     Red
# 607.0      Fire    Flash Fire  Flame Body     Shadow Tag   White
# 608.0      Fire    Flash Fire  Flame Body     Shadow Tag   Black
# 609.0      Fire    Flash Fire  Flame Body     Shadow Tag   Black
# 631.0                Gluttony  Flash Fire    White Smoke     Red
# 636.0      Fire    Flame Body                      Swarm   White
# 637.0      Fire    Flame Body                      Swarm   White
# 643.0      Fire    Turboblaze                              White
# 653.0                   Blaze                   Magician     Red
# 654.0                   Blaze                   Magician     Red
# 655.0   Psychic         Blaze                   Magician     Red
# 667.0    Normal       Rivalry     Unnerve          Moxie   Brown
# 668.0    Normal       Rivalry     Unnerve          Moxie   Brown
# 721.0     Water  Water Absorb                              Brown
# 725.0                  Blaze   Intimidate                    Red
# 726.0                  Blaze   Intimidate                    Red
# 727.0      Dark        Blaze   Intimidate                    Red
# 757.0      Fire    Corrosion    Oblivious      Oblivious   Black
# 758.0      Fire    Corrosion    Oblivious      Oblivious   Black
# 776.0    Dragon   Shell Armor                                Red

# %% [markdown]
# ## Sorting
# Dataframes can be sorted by value

# %%
pokedex_df.sort_values('Pokemon', ascending=False) # Sort by name descending
# Out:
#          Pokemon   HP  Atk  Def  SpAtk  SpDef  Speed  Total   Type I Type II  \
# Index
# 718.0    Zygarde  108  100  121     81     95     95    600   Dragon  Ground
# 634.0   Zweilous   72   85   70     65     70     58    420     Dark  Dragon
# 44.0       Zubat   40   45   35     30     40     55    245   Poison  Flying
# 570.0      Zorua   40   65   40     80     40     65    330     Dark
# 571.0    Zoroark   60  105   60    120     60    105    510     Dark
# ...          ...  ...  ...  ...    ...    ...    ...    ...      ...     ...
# 681.0  Aegislash   60   50  150     50    150     60    520    Steel   Ghost
# 617.0   Accelgor   80   70   40    100     60    145    495      Bug
# 388.0      Absol   65  130   60     75     60     75    465     Dark
# 69.0        Abra   25   20   15    105     55     90    310  Psychic
# 478.0  Abomasnow   90   92   75     92     85     60    494      Ice   Grass
#
#            Ability I   Ability II Hidden Ability   Color
# Index
# 718.0     Aura Break                               Green
# 634.0         Hustle                                Blue
# 44.0     Inner Focus                 Infiltrator  Purple
# 570.0       Illusion                                Gray
# 571.0       Illusion                                Gray
# ...              ...          ...            ...     ...
# 681.0  Stance Change                               Brown
# 617.0      Hydration  Sticky Hold       Unburden     Red
# 388.0       Pressure   Super Luck      Justified   White
# 69.0     Synchronize  Inner Focus    Magic Guard   Brown
# 478.0   Snow Warning                  Soundproof   White
#
# [820 rows x 14 columns]

# %%
# You can sort by multiple columns
pokedex_df.sort_values(['Type I','Type II', 'Total'], ascending=False) # Sort by type combination, then stats descending
# Out:
#           Pokemon   HP  Atk  Def  SpAtk  SpDef  Speed  Total Type I Type II  \
# Index
# 424.0    Empoleon   84   86   88    111    101     60    530  Water   Steel
# 565.0  Carracosta   74  108  133     83     65     32    495  Water    Rock
# 398.0   Relicanth  100   90  130     45     65     55    485  Water    Rock
# 253.0     Corsola   55   55   85     65     85     35    380  Water    Rock
# 564.0    Tirtouga   54   78  103     53     45     22    355  Water    Rock
# ...           ...  ...  ...  ...    ...    ...    ...    ...    ...     ...
# 292.0     Cascoon   50   35   55     25     25     15    205    Bug
# 664.0  Scatterbug   38   35   40     27     25     35    200    Bug
# 10.0     Caterpie   45   30   35     20     20     45    195    Bug
# 289.0     Wurmple   45   45   35     20     30     20    195    Bug
# 430.0   Kricketot   37   25   41     25     41     25    194    Bug
#
#          Ability I     Ability II Hidden Ability   Color
# Index
# 424.0      Torrent                       Defiant    Blue
# 565.0   Solid Rock         Sturdy     Swift Swim    Blue
# 398.0   Swift Swim      Rock Head         Sturdy    Gray
# 253.0       Hustle   Natural Cure    Regenerator    Pink
# 564.0   Solid Rock         Sturdy     Swift Swim    Blue
# ...            ...            ...            ...     ...
# 292.0    Shed Skin                                Purple
# 664.0  Shield Dust  Compound Eyes   Friend Guard   Black
# 10.0   Shield Dust                      Run Away   Green
# 289.0  Shield Dust                      Run Away     Red
# 430.0    Shed Skin                      Run Away     Red
#
# [820 rows x 14 columns]

# %% [markdown]
# ## Adding columns, rows, and changing values
# You can add another column like:
# ```
# dataframe['NewColumnName'] = value
# ```
# `value` can be a single value, an array of the same size as the index of `dataframe`, a pandas `Series`, or a dictionary mapping `index: value` for entries in the dataframe index

# %%
pokedex_df['Nickname'] = None
pokedex_df
# Out:
#           Pokemon   HP  Atk  Def  SpAtk  SpDef  Speed  Total    Type I  \
# Index
# 1.0     Bulbasaur   45   49   49     65     65     45    318     Grass
# 2.0       Ivysaur   60   62   63     80     80     60    405     Grass
# 3.0      Venusaur   80   82   83    100    100     80    525     Grass
# 4.0    Charmander   39   52   43     60     50     65    309      Fire
# 5.0    Charmeleon   58   64   58     80     65     80    405      Fire
# ...           ...  ...  ...  ...    ...    ...    ...    ...       ...
# 798.0     Kartana   59  181  131     59     31    109    570     Grass
# 799.0    Guzzlord  223  101   53     97     53     43    570      Dark
# 800.0    Necrozma   97  107  101    127     89     79    600   Psychic
# 801.0    Magearna   80   95  115    130    115     65    600     Steel
# 802.0   Marshadow   90  125   80     90     90    125    600  Fighting
#
#       Type II    Ability I Ability II Hidden Ability  Color Nickname
# Index
# 1.0    Poison     Overgrow               Chlorophyll  Green     None
# 2.0    Poison     Overgrow               Chlorophyll  Green     None
# 3.0    Poison     Overgrow               Chlorophyll  Green     None
# 4.0                  Blaze               Solar Power    Red     None
# 5.0                  Blaze               Solar Power    Red     None
# ...       ...          ...        ...            ...    ...      ...
# 798.0   Steel  Beast Boost                            White     None
# 799.0  Dragon  Beast Boost                            Black     None
# 800.0          Prism Armor                            Black     None
# 801.0   Fairy   Soul-Heart                             Gray     None
# 802.0   Ghost   Technician                             Gray     None
#
# [820 rows x 15 columns]

# %%
# you can change the value of an entry using indexing and assignment =
pokedex_df.loc[4,'Nickname'] = 'Abby' # indexing using .loc[] pokedex entry 4, 'Nickname column'
pokedex_df.iloc[113,-1] = 'Terry' # indexing using .iloc[] 113rd row, last column
pokedex_df.iloc[[3,113],:]
# Out:
#           Pokemon  HP  Atk  Def  SpAtk  SpDef  Speed  Total Type I Type II  \
# Index
# 4.0    Charmander  39   52   43     60     50     65    309   Fire
# 129.0     Tangela  65   55  115    100     40     60    435  Grass
#
#          Ability I  Ability II Hidden Ability Color Nickname
# Index
# 4.0          Blaze                Solar Power   Red     Abby
# 129.0  Chlorophyll  Leaf Guard    Regenerator  Blue    Terry

# %% [markdown]
# ## Combining Dataframes
# ### Appending

# %% [markdown]
# Some of you may have noticed that the pokedex file only includes Generations 1-7 of pokemon. Let's add the pokemon from Gen 8. The file `pokedex_gen8.csv` contains the pokedex entries for all of the pokemon that show up in the 8th generation of games (Sword/Shield).

# %%
# you can add another dataframe on to the end using append()
gen8_pokedex_df = pd.read_csv('pokedex_gen8.csv') # create a dataframe with new entries

# %%
appended_pokedex_df = pd.concat([pokedex_df, gen8_pokedex_df], ignore_index=True, sort=False) # the sort=False keyword prevents the columns from being reordered alphabetically
appended_pokedex_df = appended_pokedex_df.fillna('').drop_duplicates() # some cleanup operations, replace NaN with emptry strings, and drop duplicate rows
appended_pokedex_df
# Out:
#          Pokemon   HP  Atk  Def  SpAtk  SpDef  Speed  Total    Type I Type II  \
# 0      Bulbasaur   45   49   49     65     65     45  318.0     Grass  Poison
# 1        Ivysaur   60   62   63     80     80     60  405.0     Grass  Poison
# 2       Venusaur   80   82   83    100    100     80  525.0     Grass  Poison
# 3     Charmander   39   52   43     60     50     65  309.0      Fire
# 4     Charmeleon   58   64   58     80     65     80  405.0      Fire
# ...          ...  ...  ...  ...    ...    ...    ...    ...       ...     ...
# 1215    Drakloak   68   80   50     60     50    102           dragon   ghost
# 1216   Dragapult   88  120   75    100     75    142           dragon   ghost
# 1217      Zacian   92  130  115     80    115    138            fairy
# 1218   Zamazenta   92  130  115     80    115    138         fighting
# 1219   Eternatus  140   85   95    145     95    130           poison  dragon
#
#              Ability I   Ability II Hidden Ability  Color Nickname  \
# 0             Overgrow                 Chlorophyll  Green
# 1             Overgrow                 Chlorophyll  Green
# 2             Overgrow                 Chlorophyll  Green
# 3                Blaze                 Solar Power    Red     Abby
# 4                Blaze                 Solar Power    Red
# ...                ...          ...            ...    ...      ...
# 1215        Clear Body  Infiltrator    Cursed Body
# 1216        Clear Body  Infiltrator    Cursed Body
# 1217    Intrepid Sword
# 1218  Dauntless Shield
# 1219          Pressure
#
#      Galar Pokedex Number Weight_kg Height_m Weight_lbs Height_ft Cap_Rate  \
# 0
# 1
# 2
# 3
# 4
# ...                   ...       ...      ...        ...       ...      ...
# 1215                396.0      11.0      1.4       24.3     4.583     45.0
# 1216                397.0      50.0      3.0      110.2     9.833     45.0
# 1217                398.0     110.0      2.8      242.5     9.167     10.0
# 1218                399.0     210.0      2.9      463.0       9.5     10.0
# 1219                400.0     950.0     20.0     2094.4    65.583    255.0
#
#      Egg_Steps     Classification
# 0
# 1
# 2
# 3
# 4
# ...        ...                ...
# 1215   10240.0  Caretaker Pokémon
# 1216   10240.0    Stealth Pokémon
# 1217   30720.0    Warrior Pokémon
# 1218   30720.0    Warrior Pokémon
# 1219   30720.0   Gigantic Pokémon
#
# [1220 rows x 23 columns]

# %% [markdown]
# However, you may notice that some pokemon show up twice in the combined dataframe, and since the entries in `gen8_pokedex_df` includes different columns, `remove_duplicates` does not see those entries as duplicates.
#
# To remedy this, we can index both dataframes by the name of the pokemon and use the [`combine_first`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.combine_first.html#pandas.DataFrame.combine_first) function to fill in the null values of one dataframe with the corresponding values in the other.

# %%
gen8_pokedex_indexed_by_name = gen8_pokedex_df.reset_index().set_index('Pokemon')
combined_pokedex_df = pokedex_indexed_by_name.combine_first(gen8_pokedex_indexed_by_name) #very interesting
combined_pokedex_df
# Out:
#                Ability I   Ability II  Atk  Cap_Rate        Classification  \
# Pokemon
# Abomasnow   Snow Warning                92      60.0  Frosted Tree Pokémon
# Abra         Synchronize  Inner Focus   20       NaN                   NaN
# Absol           Pressure   Super Luck  130       NaN                   NaN
# Accelgor       Hydration  Sticky Hold   70      75.0     Shell Out Pokémon
# Aegislash  Stance Change                50      45.0   Royal Sword Pokémon
# ...                  ...          ...  ...       ...                   ...
# Zoroark         Illusion               105       NaN                   NaN
# Zorua           Illusion                65       NaN                   NaN
# Zubat        Inner Focus                45       NaN                   NaN
# Zweilous          Hustle                85      45.0       Hostile Pokémon
# Zygarde       Aura Break               100       NaN                   NaN
#
#             Color  Def  Egg_Steps  Galar Pokedex Number   HP  Height_ft  \
# Pokemon
# Abomasnow   White   75     5120.0                  97.0   90      7.250
# Abra        Brown   15        NaN                   NaN   25        NaN
# Absol       White   60        NaN                   NaN   65        NaN
# Accelgor      Red   40     3840.0                 276.0   80      2.583
# Aegislash   Brown  150     5120.0                 332.0   60      5.583
# ...           ...  ...        ...                   ...  ...        ...
# Zoroark      Gray   60        NaN                   NaN   60        NaN
# Zorua        Gray   40        NaN                   NaN   40        NaN
# Zubat      Purple   35        NaN                   NaN   40        NaN
# Zweilous     Blue   70    10240.0                 387.0   72      4.583
# Zygarde     Green  121        NaN                   NaN  108        NaN
#
#            Height_m Hidden Ability  Index  SpAtk  SpDef  Speed  Total  \
# Pokemon
# Abomasnow       2.2     Soundproof  478.0     92     85     60  494.0
# Abra            NaN    Magic Guard   69.0    105     55     90  310.0
# Absol           NaN      Justified  388.0     75     60     75  465.0
# Accelgor        0.8       Unburden  617.0    100     60    145  495.0
# Aegislash       1.7                 681.0     50    150     60  520.0
# ...             ...            ...    ...    ...    ...    ...    ...
# Zoroark         NaN                 571.0    120     60    105  510.0
# Zorua           NaN                 570.0     80     40     65  330.0
# Zubat           NaN    Infiltrator   44.0     30     40     55  245.0
# Zweilous        1.4                 634.0     65     70     58  420.0
# Zygarde         NaN                 718.0     81     95     95  600.0
#
#             Type I Type II  Weight_kg  Weight_lbs  index
# Pokemon
# Abomasnow      Ice   Grass      135.5       298.7   96.0
# Abra       Psychic                NaN         NaN    NaN
# Absol         Dark                NaN         NaN    NaN
# Accelgor       Bug               25.3        55.8  275.0
# Aegislash    Steel   Ghost       53.0       116.8  331.0
# ...            ...     ...        ...         ...    ...
# Zoroark       Dark                NaN         NaN    NaN
# Zorua         Dark                NaN         NaN    NaN
# Zubat       Poison  Flying        NaN         NaN    NaN
# Zweilous      Dark  Dragon       50.0       110.2  386.0
# Zygarde     Dragon  Ground        NaN         NaN    NaN
#
# [909 rows x 23 columns]

# %% [markdown]
# ### Merges and Joins
# A more advanced way to join dataframes is using the `merge` or `join` operations.
#
# For those who have worked with SQL-style databases before, you may be familiar with `merge` and `join` operations. They are done to combine two tables or dataframes which share values in certain columns. This allows us to look up entries in another dataframe using the values of our current dataframe.
#
# In this example, we will use `merge` to get the stats for a team of pokemon. This dataframe will just contain the names and nicknames of the pokemon that we want on our team. After we perform a merge, we will get a dataframe with the respective statistics for the pokemon we've chosen.

# %%
# feel free to replace the names of pokemon with ones you want on your team
team_df = pd.DataFrame({'my pokemon':['Bulbasaur','Squirtle','Charmander'],
                       'nickname':['leafygurl','h2woah','toaster']})
team_df
# Out:
#    my pokemon   nickname
# 0   Bulbasaur  leafygurl
# 1    Squirtle     h2woah
# 2  Charmander    toaster

# %% [markdown]
# There are four merge/join types in `pandas`:
# - (INNER) JOIN: Returns records that have matching values in both tables
# - (LEFT) JOIN: Returns all records from the left table, and the matched records from the right table
# - (RIGHT) JOIN: Returns all records from the right table, and the matched records from the left table
# - (OUTER) JOIN: Returns all records when there is a match in either left or right table
#
#
#  ![inner join illustration, venn diagram with intersection colored in, from w3schools sql lesson](https://www.w3schools.com/sql/img_innerjoin.gif)
#   ![left join illustration, venn diagram with full left circle colored in, from w3schools sql lesson](https://www.w3schools.com/sql/img_leftjoin.gif)
#   ![right join illustration, venn diagram with full right circle colored in, from w3schools sql lesson](https://www.w3schools.com/sql/img_rightjoin.gif)
#   ![outer join illustration, venn diagram with union of two circles colored in, from w3schools sql lesson](https://www.w3schools.com/sql/img_fulljoin.gif)
#
# The information that we need in order to perform a merge is:
# - what dataframes to merge
# - what kind of merge/join (inner/left/right/outer)
# - what columns to merge on in each dataframe
#
# Knowing this, let's look at the function signature of merge for a dataframe

# %%
# you can use the question mark symbol ? to examine the function signature
pokedex_df.merge?
# Out:
# Signature:
# pokedex_df.merge(
#     right: 'DataFrame | Series',
#     how: 'MergeHow' = 'inner',
#     on: 'IndexLabel | None' = None,
#     left_on: 'IndexLabel | None' = None,
#     right_on: 'IndexLabel | None' = None,
#     left_index: 'bool' = False,
#     right_index: 'bool' = False,
#     sort: 'bool' = False,
#     suffixes: 'Suffixes' = ('_x', '_y'),
#     copy: 'bool | None' = None,
#     indicator: 'str | bool' = False,
#     validate: 'MergeValidate | None' = None,
# ) -> 'DataFrame'
# Docstring:
# Merge DataFrame or named Series objects with a database-style join.
#
# A named Series object is treated as a DataFrame with a single named column.
#
# The join is done on columns or indexes. If joining columns on
# columns, the DataFrame indexes *will be ignored*. Otherwise if joining indexes
# on indexes or indexes on a column or columns, the index will be passed on.
# When performing a cross merge, no column specifications to merge on are
# allowed.
#
# .. warning::
#
#     If both key columns contain rows where the key is a null value, those
#     rows will be matched against each other. This is different from usual SQL
#     join behaviour and can lead to unexpected results.
#
# Parameters
# ----------
# right : DataFrame or named Series
#     Object to merge with.
# how : {'left', 'right', 'outer', 'inner', 'cross'}, default 'inner'
#     Type of merge to be performed.
#
#     * left: use only keys from left frame, similar to a SQL left outer join;
#       preserve key order.
#     * right: use only keys from right frame, similar to a SQL right outer join;
#       preserve key order.
#     * outer: use union of keys from both frames, similar to a SQL full outer
#       join; sort keys lexicographically.
#     * inner: use intersection of keys from both frames, similar to a SQL inner
#       join; preserve the order of the left keys.
#     * cross: creates the cartesian product from both frames, preserves the order
#       of the left keys.
#
#       .. versionadded:: 1.2.0
#
# on : label or list
#     Column or index level names to join on. These must be found in both
#     DataFrames. If `on` is None and not merging on indexes then this defaults
#     to the intersection of the columns in both DataFrames.
# left_on : label or list, or array-like
#     Column or index level names to join on in the left DataFrame. Can also
#     be an array or list of arrays of the length of the left DataFrame.
#     These arrays are treated as if they are columns.
# right_on : label or list, or array-like
#     Column or index level names to join on in the right DataFrame. Can also
#     be an array or list of arrays of the length of the right DataFrame.
#     These arrays are treated as if they are columns.
# left_index : bool, default False
#     Use the index from the left DataFrame as the join key(s). If it is a
#     MultiIndex, the number of keys in the other DataFrame (either the index
#     or a number of columns) must match the number of levels.
# right_index : bool, default False
#     Use the index from the right DataFrame as the join key. Same caveats as
#     left_index.
# sort : bool, default False
#     Sort the join keys lexicographically in the result DataFrame. If False,
#     the order of the join keys depends on the join type (how keyword).
# suffixes : list-like, default is ("_x", "_y")
#     A length-2 sequence where each element is optionally a string
#     indicating the suffix to add to overlapping column names in
#     `left` and `right` respectively. Pass a value of `None` instead
#     of a string to indicate that the column name from `left` or
#     `right` should be left as-is, with no suffix. At least one of the
#     values must not be None.
# copy : bool, default True
#     If False, avoid copy if possible.
# indicator : bool or str, default False
#     If True, adds a column to the output DataFrame called "_merge" with
#     information on the source of each row. The column can be given a different
#     name by providing a string argument. The column will have a Categorical
#     type with the value of "left_only" for observations whose merge key only
#     appears in the left DataFrame, "right_only" for observations
#     whose merge key only appears in the right DataFrame, and "both"
#     if the observation's merge key is found in both DataFrames.
#
# validate : str, optional
#     If specified, checks if merge is of specified type.
#
#     * "one_to_one" or "1:1": check if merge keys are unique in both
#       left and right datasets.
#     * "one_to_many" or "1:m": check if merge keys are unique in left
#       dataset.
#     * "many_to_one" or "m:1": check if merge keys are unique in right
#       dataset.
#     * "many_to_many" or "m:m": allowed, but does not result in checks.
#
# Returns
# -------
# DataFrame
#     A DataFrame of the two merged objects.
#
# See Also
# --------
# merge_ordered : Merge with optional filling/interpolation.
# merge_asof : Merge on nearest keys.
# DataFrame.join : Similar method using indices.
#
# Examples
# --------
# >>> df1 = pd.DataFrame({'lkey': ['foo', 'bar', 'baz', 'foo'],
# ...                     'value': [1, 2, 3, 5]})
# >>> df2 = pd.DataFrame({'rkey': ['foo', 'bar', 'baz', 'foo'],
# ...                     'value': [5, 6, 7, 8]})
# >>> df1
#     lkey value
# 0   foo      1
# 1   bar      2
# 2   baz      3
# 3   foo      5
# >>> df2
#     rkey value
# 0   foo      5
# 1   bar      6
# 2   baz      7
# 3   foo      8
#
# Merge df1 and df2 on the lkey and rkey columns. The value columns have
# the default suffixes, _x and _y, appended.
#
# >>> df1.merge(df2, left_on='lkey', right_on='rkey')
#   lkey  value_x rkey  value_y
# 0  foo        1  foo        5
# 1  foo        1  foo        8
# 2  foo        5  foo        5
# 3  foo        5  foo        8
# 4  bar        2  bar        6
# 5  baz        3  baz        7
#
# Merge DataFrames df1 and df2 with specified left and right suffixes
# appended to any overlapping columns.
#
# >>> df1.merge(df2, left_on='lkey', right_on='rkey',
# ...           suffixes=('_left', '_right'))
#   lkey  value_left rkey  value_right
# 0  foo           1  foo            5
# 1  foo           1  foo            8
# 2  foo           5  foo            5
# 3  foo           5  foo            8
# 4  bar           2  bar            6
# 5  baz           3  baz            7
#
# Merge DataFrames df1 and df2, but raise an exception if the DataFrames have
# any overlapping columns.
#
# >>> df1.merge(df2, left_on='lkey', right_on='rkey', suffixes=(False, False))
# Traceback (most recent call last):
# ...
# ValueError: columns overlap but no suffix specified:
#     Index(['value'], dtype='object')
#
# >>> df1 = pd.DataFrame({'a': ['foo', 'bar'], 'b': [1, 2]})
# >>> df2 = pd.DataFrame({'a': ['foo', 'baz'], 'c': [3, 4]})
# >>> df1
#       a  b
# 0   foo  1
# 1   bar  2
# >>> df2
#       a  c
# 0   foo  3
# 1   baz  4
#
# >>> df1.merge(df2, how='inner', on='a')
#       a  b  c
# 0   foo  1  3
#
# >>> df1.merge(df2, how='left', on='a')
#       a  b  c
# 0   foo  1  3.0
# 1   bar  2  NaN
#
# >>> df1 = pd.DataFrame({'left': ['foo', 'bar']})
# >>> df2 = pd.DataFrame({'right': [7, 8]})
# >>> df1
#     left
# 0   foo
# 1   bar
# >>> df2
#     right
# 0   7
# 1   8
#
# >>> df1.merge(df2, how='cross')
#    left  right
# 0   foo      7
# 1   foo      8
# 2   bar      7
# 3   bar      8
# File:      /opt/conda/lib/python3.11/site-packages/pandas/core/frame.py
# Type:      method

# %% [markdown]
# The answers to the following questions to get the team dataframe with stats are:
#
# **what dataframes to merge?**
# `team_df` and `combined_pokedex_df`
#
# **what kind of merge/join (inner/left/right/outer)?**
# inner or left
#
# **what columns to merge on in each dataframe**
# for `team_df`, the column is `my pokemon`, for `combined_pokedex_df`, it is the index.

# %%
team_with_stats = team_df.merge(combined_pokedex_df, how='inner',
                               left_on='my pokemon', right_index=True)

"""
Krish: In this case how='left' will give the same result. This is becaue you take verything from 
team_df, and then go and append those columns with the shared data from combined_pokedex_df.
"""
team_with_stats
# Out:
#    my pokemon   nickname Ability I Ability II  Atk  Cap_Rate  Classification  \
# 0   Bulbasaur  leafygurl  Overgrow              49       NaN             NaN
# 1    Squirtle     h2woah   Torrent              48       NaN             NaN
# 2  Charmander    toaster     Blaze              52      45.0  Lizard Pokémon
#
#    Color  Def  Egg_Steps  Galar Pokedex Number  HP  Height_ft  Height_m  \
# 0  Green   49        NaN                   NaN  45        NaN       NaN
# 1   Blue   65        NaN                   NaN  44        NaN       NaN
# 2    Red   43     5120.0                 378.0  39        2.0       0.6
#
#   Hidden Ability  Index  SpAtk  SpDef  Speed  Total Type I Type II  Weight_kg  \
# 0    Chlorophyll    1.0     65     65     45  318.0  Grass  Poison        NaN
# 1      Rain Dish    7.0     60     54     43  314.0  Water                NaN
# 2    Solar Power    4.0     60     50     65  309.0   Fire                8.5
#
#    Weight_lbs  index
# 0         NaN    NaN
# 1         NaN    NaN
# 2        18.7  377.0

# %%
# we can select specific columns from the dataframe
team_with_stats.loc[:,['my pokemon','nickname','Total']]
# Out:
#    my pokemon   nickname  Total
# 0   Bulbasaur  leafygurl  318.0
# 1    Squirtle     h2woah  314.0
# 2  Charmander    toaster  309.0

# %% [markdown]
# ### Exercise
# Put together a team of pokemon by editing `team_df` and performing a `merge`. Remember that you can only have 6 pokemon on a team at once.

# %% [markdown]
# ## Calculations and operations
# There are various ways to do math to the dataframes

# %% [markdown]
# ### Column operations
# You can perform basic math element-wise between columns, such as addition, subtraction, multiplication, and division.
#
# Note that the `gen8_pokedex_df` does not contain a `Total` stats column, so currently the gen8 pokemon have `NaN` in that column. We can fix that, because `Total` is generated as the sum of the respective `HP` `Atk` `Def` `SpAtk` `SpDef` and `Speed`. We can add the entire columns at once, without having to loop over each entry. Pandas supports vectorized operations behind the scenes.

# %%
# these are the entries missing 'Total' stats
combined_pokedex_df.loc[combined_pokedex_df['Total'].isnull()]
# Out:
#                     Ability I      Ability II  Atk  Cap_Rate  \
# Pokemon
# Alcremie           Sweet Veil             NaN   60     100.0
# Appletun                Ripen        Gluttony   85      45.0
# Applin                  Ripen        Gluttony   40     255.0
# Arctovish        Water Absorb        Ice Body   90      45.0
# Arctozolt         Volt Absorb          Static  100      45.0
# Arrokuda           Swift Swim             NaN   63     255.0
# Barraskewda        Swift Swim             NaN  123      60.0
# Blipbug                 Swarm    Compoundeyes   20     255.0
# Boltund            Strong Jaw             NaN   90      45.0
# Carkol           Steam Engine      Flame Body   60     120.0
# Centiskorch        Flash Fire     White Smoke  115      75.0
# Chewtle            Strong Jaw     Shell Armor   64     255.0
# Cinderace               Blaze             NaN  116      45.0
# Clobbopus              Limber             NaN   68     180.0
# Coalossal        Steam Engine      Flame Body   80      45.0
# Copperajah        Sheer Force             NaN  130      90.0
# Corviknight          Pressure         Unnerve   87      45.0
# Corvisquire          Keen Eye         Unnerve   67     120.0
# Cramorant        Gulp Missile             NaN   85      45.0
# Cufant            Sheer Force             NaN   80     190.0
# Cursola            Weak Armor             NaN   95      30.0
# Dottler                 Swarm    Compoundeyes   35     120.0
# Dracovish        Water Absorb      Strong Jaw   90      45.0
# Dracozolt         Volt Absorb          Hustle  100      45.0
# Dragapult          Clear Body     Infiltrator  120      45.0
# Drakloak           Clear Body     Infiltrator   80      45.0
# Drednaw            Strong Jaw     Shell Armor  115      75.0
# Dreepy             Clear Body     Infiltrator   60      45.0
# Drizzile              Torrent             NaN   60      45.0
# Dubwool                Fluffy       Steadfast   80     127.0
# Duraludon         Light Metal     Heavy Metal   95      45.0
# Eiscue               Ice Face             NaN   80      60.0
# Eldegoss          Cotton Down     Regenerator   50      75.0
# Eternatus            Pressure             NaN   85     255.0
# Falinks          Battle Armor             NaN  100      45.0
# Farfetchd           Steadfast             NaN   95      45.0
# Flapple                 Ripen        Gluttony  110      45.0
# Frosmoth          Shield Dust             NaN   65      75.0
# Gossifleur        Cotton Down     Regenerator   40     190.0
# Grapploct              Limber             NaN  118      45.0
# Greedent          Cheek Pouch             NaN   95      90.0
# Grimmsnarl          Prankster           Frisk  120      45.0
# Grookey              Overgrow             NaN   65      45.0
# Hakamoo           Bulletproof      Soundproof   75      45.0
# Hatenna                Healer    Anticipation   30     235.0
# Hatterene              Healer    Anticipation   90      45.0
# Hattrem                Healer    Anticipation   40     120.0
# Impidimp            Prankster           Frisk   45     255.0
# Indeedee          Inner Focus     Synchronize   65      30.0
# Inteleon              Torrent             NaN   85      45.0
# Jangmoo           Bulletproof      Soundproof   55      45.0
# Kommoo            Bulletproof      Soundproof  110      45.0
# Milcery            Sweet Veil             NaN   40     200.0
# MimeJr             Soundproof          Filter   25     145.0
# Morgrem             Prankster           Frisk   60     120.0
# Morpeko         Hunger Switch             NaN   95     180.0
# MrMime           Vital Spirit  Screen Cleaner   65      45.0
# MrRime           Tangled Feet  Screen Cleaner   85      45.0
# Nickit               Run Away        Unburden   28     255.0
# Obstagoon            Reckless            Guts   90      45.0
# Orbeetle                Swarm           Frisk   45      45.0
# Perrserker       Battle Armor     Tough Claws  110      90.0
# Pincurchin      Lightning Rod             NaN  101      75.0
# Polteageist        Weak Armor             NaN   65      60.0
# Raboot                  Blaze             NaN   86      45.0
# Rillaboom            Overgrow             NaN  125      45.0
# Rolycoly         Steam Engine       Heatproof   40     255.0
# Rookidee             Keen Eye         Unnerve   47     255.0
# Runerigus    Wandering Spirit             NaN   95      90.0
# Sandaconda          Sand Spit       Shed Skin  107     120.0
# Scorbunny               Blaze             NaN   71      45.0
# Silicobra           Sand Spit       Shed Skin   57     255.0
# Sinistea           Weak Armor             NaN   45     120.0
# Sirfetchd           Steadfast             NaN  135      45.0
# Sizzlipede         Flash Fire     White Smoke   65     190.0
# Skwovet           Cheek Pouch             NaN   55     255.0
# Snom              Shield Dust             NaN   25     190.0
# Sobble                Torrent             NaN   40      45.0
# Stonjourner        Power Spot             NaN  125      60.0
# Thievul              Run Away        Unburden   58     127.0
# Thwackey             Overgrow             NaN   85      45.0
# Toxel                 Rattled          Static   38      75.0
# Toxtricity          Punk Rock            Plus   98      45.0
# TypeNull         Battle Armor             NaN   95       3.0
# Wishiwashi          Schooling             NaN   20      60.0
# Wooloo                 Fluffy        Run Away   40     255.0
# Yamper             Ball Fetch             NaN   45     255.0
# Zacian         Intrepid Sword             NaN  130      10.0
# Zamazenta    Dauntless Shield             NaN  130      10.0
#
#                    Classification Color  Def  Egg_Steps  Galar Pokedex Number  \
# Pokemon
# Alcremie            Cream Pokémon   NaN   75     5120.0                 186.0
# Appletun     Apple Nectar Pokémon   NaN   80     5120.0                 207.0
# Applin         Apple Core Pokémon   NaN   80     5120.0                 205.0
# Arrokuda      41      1.667       0.5  Propeller Tail    NaN     40     30
# Barraskewda   61      4.250       1.3  Propeller Tail    NaN     60     50
# Blipbug       25      1.333       0.4       Telepathy    NaN     25     45
# Boltund       69      3.250       1.0     Competitive    NaN     90     60
# Carkol        80      3.583       1.1      Flash Fire    NaN     60     70
# Centiskorch  100      9.833       3.0      Flame Body    NaN     90     90
# Chewtle       50      1.000       0.3      Swift Swim    NaN     38     38
# Cinderace     80      4.583       1.4          Libero    NaN     65     75
# Clobbopus     50      2.000       0.6      Technician    NaN     50     50
# Coalossal    110      9.167       2.8      Flash Fire    NaN     80     90
# Copperajah   122      9.833       3.0     Heavy Metal    NaN     80     69
# Corviknight   98      7.250       2.2    Mirror Armor    NaN     53     85
# Corvisquire   68      2.583       0.8       Big Pecks    NaN     43     55
# Cramorant     70      2.583       0.8             NaN    NaN     85     95
# Cufant        72      3.917       1.2     Heavy Metal    NaN     40     49
# Cursola       60      3.250       1.0     Perish Body    NaN    145    130
# Dottler       50      1.333       0.4       Telepathy    NaN     50     90
# Dracovish     90      7.583       2.3       Sand Rush    NaN     70     80
# Dracozolt     90      5.917       1.8       Sand Rush    NaN     80     70
# Dragapult     88      9.833       3.0     Cursed Body    NaN    100     75
# Drakloak      68      4.583       1.4     Cursed Body    NaN     60     50
# Drednaw       90      3.250       1.0      Swift Swim    NaN     48     68
# Dreepy        28      1.667       0.5     Cursed Body    NaN     40     30
# Drizzile      65      2.333       0.7          Sniper    NaN     95     55
# Dubwool       72      4.250       1.3     Bulletproof    NaN     60     90
# Duraludon     70      5.917       1.8        Stalwart    NaN    120     50
# Eiscue        75      4.583       1.4             NaN    NaN     65     90
# Eldegoss      60      1.667       0.5    Effect Spore    NaN     80    120
# Eternatus    140     65.583      20.0             NaN    NaN    145     95
# Falinks       65      9.833       3.0         Defiant    NaN     70     60
# Farfetchd     52      2.583       0.8         Scrappy    NaN     58     62
# Flapple       70      1.000       0.3          Hustle    NaN     95     60
# Frosmoth      70      4.250       1.3      Ice Scales    NaN    125     90
# Gossifleur    40      1.333       0.4    Effect Spore    NaN     40     60
# Grapploct     80      5.250       1.6      Technician    NaN     70     80
# Greedent     120      2.000       0.6        Gluttony    NaN     55     75
# Grimmsnarl    95      4.917       1.5      Pickpocket    NaN     95     75
# Grookey       50      1.000       0.3    Grassy Surge    NaN     40     40
# Hakamoo       55      3.917       1.2        Overcoat    NaN     65     70
# Hatenna       42      1.333       0.4    Magic Bounce    NaN     56     53
# Hatterene     57      6.917       2.1    Magic Bounce    NaN    136    103
# Hattrem       57      2.000       0.6    Magic Bounce    NaN     86     73
# Impidimp      45      1.333       0.4      Pickpocket    NaN     55     40
# Indeedee      60      2.917       0.9   Psychic Surge    NaN    105     95
# Inteleon      70      6.250       1.9          Sniper    NaN    125     65
# Jangmoo       45      2.000       0.6        Overcoat    NaN     45     45
# Kommoo        75      5.250       1.6        Overcoat    NaN    100    105
# Milcery       45      0.667       0.2      Aroma Veil    NaN     50     61
# MimeJr        20      2.000       0.6      Technician    NaN     70     90
# Morgrem       65      2.583       0.8      Pickpocket    NaN     75     55
# Morpeko       58      1.000       0.3             NaN    NaN     70     58
# MrMime        50      4.250       1.3        Ice Body    NaN     90     90
# MrRime        80      4.917       1.5        Ice Body    NaN    110    100
# Nickit        40      2.000       0.6        Stakeout    NaN     47     52
# Obstagoon     93      5.250       1.6         Defiant    NaN     60     81
# Orbeetle      60      1.333       0.4       Telepathy    NaN     80    120
# Perrserker    70      2.583       0.8   Steely Spirit    NaN     50     60
# Pincurchin    48      1.000       0.3  Electric Surge    NaN     91     85
# Polteageist   60      0.667       0.2     Cursed Body    NaN    134    114
# Raboot        65      2.000       0.6          Libero    NaN     55     60
# Rillaboom    100      6.917       2.1    Grassy Surge    NaN     60     70
# Rolycoly      30      1.000       0.3      Flash Fire    NaN     40     50
# Rookidee      38      0.667       0.2       Big Pecks    NaN     33     35
# Runerigus     58      5.250       1.6             NaN    NaN     50    105
# Sandaconda    72     12.500       3.8       Sand Veil    NaN     65     70
# Scorbunny     50      1.000       0.3          Libero    NaN     40     40
# Silicobra     52      7.250       2.2       Sand Veil    NaN     35     50
# Sinistea      40      0.333       0.1     Cursed Body    NaN     74     54
# Sirfetchd     62      2.583       0.8         Scrappy    NaN     68     82
# Sizzlipede    50      2.333       0.7      Flame Body    NaN     50     50
# Skwovet       70      1.000       0.3        Gluttony    NaN     35     35
# Snom          30      1.000       0.3      Ice Scales    NaN     45     30
# Sobble        50      1.000       0.3          Sniper    NaN     70     40
# Stonjourner  100      8.167       2.5             NaN    NaN     20     20
# Thievul       70      3.917       1.2        Stakeout    NaN     87     92
# Thwackey      70      2.333       0.7    Grassy Surge    NaN     55     60
# Toxel         40      1.333       0.4           Klutz    NaN     54     35
# Toxtricity    75      5.250       1.6      Technician    NaN    114     70
# TypeNull      95      6.250       1.9             NaN    NaN     95     95
# Wishiwashi    45      0.667       0.2             NaN    NaN     25     25
# Wooloo        42      2.000       0.6     Bulletproof    NaN     40     45
# Yamper        59      1.000       0.3         Rattled    NaN     40     50
# Zacian        92      9.167       2.8             NaN    NaN     80    115
# Zamazenta     92      9.500       2.9             NaN    NaN     80    115
#
#              Speed  Total    Type I   Type II  Weight_kg  Weight_lbs  index
# Pokemon
# Alcremie        64    NaN     fairy       NaN        0.5         1.1  185.0
# Appletun        30    NaN     grass    dragon       13.0        28.7  206.0
# Applin          20    NaN     grass    dragon        0.5         1.1  204.0
# Arctovish       55    NaN     water       ice      175.0       385.8  376.0
# Arctozolt       55    NaN  electric       ice      150.0       330.7  374.0
# Arrokuda        66    NaN     water       NaN        1.0         2.2  179.0
# Barraskewda    136    NaN     water       NaN       30.0        66.1  180.0
# Blipbug         45    NaN       bug       NaN        8.0        17.6    9.0
# Boltund        121    NaN  electric       NaN       34.0        75.0   46.0
# Carkol          50    NaN      rock      fire       78.0       172.0  161.0
# Centiskorch     65    NaN      fire       bug      120.0       264.6  159.0
# Chewtle         44    NaN     water       NaN        8.5        18.7   41.0
# Cinderace      119    NaN      fire       NaN       33.0        72.8    5.0
# Clobbopus       32    NaN  fighting       NaN        4.0         8.8  350.0
# Coalossal       30    NaN      rock      fire      310.5       684.5  162.0
# Copperajah      30    NaN     steel       NaN      650.0      1433.0  302.0
# Corviknight     67    NaN    flying     steel       75.0       165.3   22.0
# Corvisquire     77    NaN    flying       NaN       16.0        35.3   21.0
# Cramorant       85    NaN    flying     water       18.0        39.7  308.0
# Cufant          40    NaN     steel       NaN      100.0       220.5  301.0
# Cursola         30    NaN     ghost       NaN        0.4         0.9  236.0
# Dottler         30    NaN       bug   psychic       19.5        43.0   10.0
# Dracovish       75    NaN     water    dragon      215.0       474.0  375.0
# Dracozolt       75    NaN  electric    dragon      190.0       418.9  373.0
# Dragapult      142    NaN    dragon     ghost       50.0       110.2  396.0
# Drakloak       102    NaN    dragon     ghost       11.0        24.3  395.0
# Drednaw         74    NaN     water      rock      115.5       254.6   42.0
# Dreepy          82    NaN    dragon     ghost        2.0         4.4  394.0
# Drizzile        90    NaN     water       NaN       11.5        25.4    7.0
# Dubwool         88    NaN    normal       NaN       43.0        94.8   34.0
# Duraludon       85    NaN     steel    dragon       40.0        88.2  370.0
# Eiscue          50    NaN       ice       NaN       89.0       196.2  369.0
# Eldegoss        60    NaN     grass       NaN        2.5         5.5  126.0
# Eternatus      130    NaN    poison    dragon      950.0      2094.4  399.0
# Falinks         75    NaN  fighting       NaN       62.0       136.7  344.0
# Farfetchd       55    NaN  fighting       NaN       15.0        33.1  217.0
# Flapple         70    NaN     grass    dragon        1.0         2.2  205.0
# Frosmoth        65    NaN       ice       bug       42.0        92.6  349.0
# Gossifleur      10    NaN     grass       NaN        2.2         4.9  125.0
# Grapploct       42    NaN  fighting       NaN       39.0        86.0  351.0
# Greedent        20    NaN    normal       NaN        6.0        13.2   24.0
# Grimmsnarl      60    NaN      dark     fairy       61.0       134.5  239.0
# Grookey         65    NaN     grass       NaN        5.0        11.0    0.0
# Hakamoo         65    NaN    dragon  fighting       47.0       103.6  392.0
# Hatenna         39    NaN   psychic       NaN        3.4         7.5  240.0
# Hatterene       29    NaN   psychic     fairy        5.1        11.2  242.0
# Hattrem         49    NaN   psychic       NaN        4.8        10.6  241.0
# Impidimp        50    NaN      dark     fairy        5.5        12.1  237.0
# Indeedee        95    NaN   psychic    normal       28.0        61.7  336.0
# Inteleon       120    NaN     water       NaN       45.2        99.6    8.0
# Jangmoo         45    NaN    dragon       NaN       29.7        65.5  391.0
# Kommoo          85    NaN    dragon  fighting       78.2       172.4  393.0
# Milcery         34    NaN     fairy       NaN        0.3         0.7  184.0
# MimeJr          60    NaN   psychic     fairy       13.0        28.7  363.0
# Morgrem         70    NaN      dark     fairy       12.5        27.6  238.0
# Morpeko         97    NaN  electric      dark        3.0         6.6  343.0
# MrMime         100    NaN       ice   psychic       54.5       120.2  364.0
# MrRime          70    NaN       ice   psychic       58.2       128.3  365.0
# Nickit          50    NaN      dark       NaN        8.9        19.6   28.0
# Obstagoon       95    NaN      dark    normal       46.0       101.4   32.0
# Orbeetle        90    NaN       bug   psychic       40.8        89.9   11.0
# Perrserker      50    NaN     steel       NaN       28.0        61.7  182.0
# Pincurchin      15    NaN  electric       NaN        1.0         2.2  352.0
# Polteageist     70    NaN     ghost       NaN        0.4         0.9  335.0
# Raboot          94    NaN      fire       NaN        9.0        19.8    4.0
# Rillaboom       85    NaN     grass       NaN       90.0       198.4    2.0
# Rolycoly        30    NaN      rock       NaN       12.0        26.5  160.0
# Rookidee        57    NaN    flying       NaN        1.8         4.0   20.0
# Runerigus       30    NaN    ground     ghost       66.6       146.8  327.0
# Sandaconda      71    NaN    ground       NaN       65.5       144.4  312.0
# Scorbunny       69    NaN      fire       NaN        4.5         9.9    3.0
# Silicobra       46    NaN    ground       NaN        7.6        16.8  311.0
# Sinistea        50    NaN     ghost       NaN        0.2         0.4  334.0
# Sirfetchd       65    NaN  fighting       NaN      117.0       257.9  218.0
# Sizzlipede      45    NaN      fire       bug        1.0         2.2  158.0
# Skwovet         25    NaN    normal       NaN        2.5         5.5   23.0
# Snom            20    NaN       ice       bug        3.8         8.4  348.0
# Sobble          70    NaN     water       NaN        4.0         8.8    6.0
# Stonjourner     70    NaN      rock       NaN      520.0      1146.4  368.0
# Thievul         90    NaN      dark       NaN       19.9        43.9   29.0
# Thwackey        80    NaN     grass       NaN       14.0        30.9    1.0
# Toxel           40    NaN  electric    poison       11.0        24.3  309.0
# Toxtricity      75    NaN  electric    poison       40.0        88.2  310.0
# TypeNull        59    NaN    normal       NaN      120.5       265.7  380.0
# Wishiwashi      40    NaN     water       NaN        0.3         0.7  154.0
# Wooloo          48    NaN    normal       NaN        6.0        13.2   33.0
# Yamper          26    NaN  electric       NaN       13.5        29.8   45.0
# Zacian         138    NaN     fairy       NaN      110.0       242.5  397.0
# Zamazenta      138    NaN  fighting       NaN      210.0       463.0  398.0

# %%
combined_pokedex_df['Total'] = combined_pokedex_df['HP']\
                               + combined_pokedex_df['Atk']\
                               + combined_pokedex_df['Def']\
                               + combined_pokedex_df['SpAtk']\
                               + combined_pokedex_df['SpDef']\
                               + combined_pokedex_df['Speed']

# %%
pokedex_df['Total']/ pokedex_df['HP'] # computes the ratio between total stats and HP
# Out:
# Index
# 1.0      7.066667
# 2.0      6.750000
# 3.0      6.562500
# 4.0      7.923077
# 5.0      6.982759
#            ...
# 798.0    9.661017
# 799.0    2.556054
# 800.0    6.185567
# 801.0    7.500000
# 802.0    6.666667
# Length: 820, dtype: float64

# %% [markdown]
# ### Universal functions
# Universal functions can operate on entire dataframes or slices of dataframes. They return a dataframe copy with the same index as the original dataframe. Numpy universal functions can be applied to any numeric dataframe or slice.

# %%
#np.log(pokedex_df.loc[:,'HP':'Total'].astype(float)) # take natural log of all stats
pokedex_df.loc[:,'HP':'Total'].apply(np.log).astype(int)
# again, these functions operate on each element independently, and return a dataframe with the same index and size of input
# Out:
#        HP  Atk  Def  SpAtk  SpDef  Speed  Total
# Index
# 1.0     3    3    3      4      4      3      5
# 2.0     4    4    4      4      4      4      6
# 3.0     4    4    4      4      4      4      6
# 4.0     3    3    3      4      3      4      5
# 5.0     4    4    4      4      4      4      6
# ...    ..  ...  ...    ...    ...    ...    ...
# 798.0   4    5    4      4      3      4      6
# 799.0   5    4    3      4      3      3      6
# 800.0   4    4    4      4      4      4      6
# 801.0   4    4    4      4      4      4      6
# 802.0   4    4    4      4      4      4      6
#
# [820 rows x 7 columns]

# %% [markdown]
# ### .apply()
# You can apply an arbitrary function to each row or column using the `.apply()` function.
#
# If you pass the name of a function (e.g. np.mean, or the name of any function you've written), you can apply it to either each column, or each row using `.apply()`

# %%
pokedex_df.loc[:,'Atk':'Speed'].apply(np.mean) # applies the function np.mean() to each column
# Out:
# Atk      76.115854
# Def      71.919512
# SpAtk    69.957317
# SpDef    70.370732
# Speed    66.140244
# dtype: float64

# %%
pokedex_df.loc[:,'Atk':'Speed'].apply(np.mean, axis=1) # if you wanted to apply it to each row instead, use the argument axis=1
# Out:
# Index
# 1.0       54.6
# 2.0       69.0
# 3.0       89.0
# 4.0       54.0
# 5.0       69.4
#          ...
# 798.0    102.2
# 799.0     69.4
# 800.0    100.6
# 801.0    104.0
# 802.0    102.0
# Length: 820, dtype: float64

# %% [markdown]
# The above example is actually a bit unnecessary. There are several built-in functions in dataframes, including a `.mean()` which has the same functionality.

# %%
pokedex_df.loc[:,'Atk':'Speed'].mean()
# Out:
# Atk      76.115854
# Def      71.919512
# SpAtk    69.957317
# SpDef    70.370732
# Speed    66.140244
# dtype: float64

# %%
pokedex_df.loc[:,'Atk':'Speed'].mean(axis=1) #applies per row
# Out:
# Index
# 1.0       54.6
# 2.0       69.0
# 3.0       89.0
# 4.0       54.0
# 5.0       69.4
#          ...
# 798.0    102.2
# 799.0     69.4
# 800.0    100.6
# 801.0    104.0
# 802.0    102.0
# Length: 820, dtype: float64

# %% [markdown]
# Most [descriptive statistics](https://pandas.pydata.org/pandas-docs/stable/reference/frame.html#computations-descriptive-stats) (median, mode, standard deviation, count, quantile, etc) have built-in functions. Where `.apply()` really shines, however, is for applying custom functions.
#
# To show that functionality, let's take a sidebar and talk about lambda functions.

# %% [markdown]
# #### Lambda functions
# Sometimes you want to define a function, but you don't want to write the whole function declaration setup
# ```
# def functionname(inputs):
#   ...
#   return outputs
# ```
#
# In those situations, you can write lambda (also known as anonymous) functions. The syntax for a lambda function is:
#
# ```
# functionname = lambda x: operations_on_x
# ```
#
# For example, if you wanted to write a function that squares the input, you could write:

# %%
square_it = lambda x: x**2 # recall that ** is exponentiation in python, this function returns the square of the input
for num in range(10):
  print(square_it(num))
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81

# %% [markdown]
# This is especially useful if some function takes another function as an argument, like panda's `.apply()`
#
# The typical usage of `.apply()` is:
#
# `dataframe_obj.apply(functionname)`, which calls `functionname` on each column of `dataframe_obj`
#
# However, you can replace `functionname` with a lambda function. In this example, we use the following lambda function:
#
# ```lambda col: [np.min(col), np.max(col)]```
#
# The word `col` represents the argument, and then to the right of the colon, we return a list with two elements: the minimum and maximum values of the column

# %%
stats_ranges = pokedex_df.loc[:,'HP':'Total'].apply(lambda col: [np.min(col), np.max(col)])
print(stats_ranges)
# Out:
#     HP  Atk  Def  SpAtk  SpDef  Speed  Total
# 0    1    5    5     10     20      5    175
# 1  255  181  230    180    230    180    720

# %% [markdown]
# the above can be expanded into a dataframe:

# %%
pokedex_df.loc[:,'HP':'Total'].apply(lambda col: [np.min(col), np.mean(col), np.max(col)], result_type='expand')
# each respective row corresponds to the function applied to the column
# Out:
#           HP         Atk         Def       SpAtk       SpDef       Speed  \
# 0    1.00000    5.000000    5.000000   10.000000   20.000000    5.000000
# 1   68.60122   76.115854   71.919512   69.957317   70.370732   66.140244
# 2  255.00000  181.000000  230.000000  180.000000  230.000000  180.000000
#
#         Total
# 0  175.000000
# 1  423.104878
# 2  720.000000

# %%
# we can rename the rows to make it more interpretable. Also note the backslash \
# character allows a command to continue onto the next line, ignoring whitespace
pokedex_df.loc[:,'HP':'Total']\
          .apply(lambda col: [np.min(col), np.mean(col), np.max(col)], result_type='expand')\
          .rename({0:'min', 1:'mean', 2:'max'})
# Out:
#              HP         Atk         Def       SpAtk       SpDef       Speed  \
# min     1.00000    5.000000    5.000000   10.000000   20.000000    5.000000
# mean   68.60122   76.115854   71.919512   69.957317   70.370732   66.140244
# max   255.00000  181.000000  230.000000  180.000000  230.000000  180.000000
#
#            Total
# min   175.000000
# mean  423.104878
# max   720.000000

# %% [markdown]
# ### Groupby
# Dataframes can be grouped by column values, and operations can be applied to each group

# %%
# counts the number of pokemon of each type combination
pokedex_df.groupby(['Type I','Type II'])['Total'].count()
# Out:
# Type I  Type II
# Bug                 18
#         Electric     4
#         Fairy        2
#         Fighting     3
#         Fire         2
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: Total, Length: 163, dtype: int64

# %%
# gets the range of stats for each type combination
pokedex_df.groupby(['Type I','Type II'])['Total'].apply(lambda col: [np.min(col), np.max(col)])
# Out:
# Type I  Type II
# Bug                 [194, 500]
#         Electric    [319, 500]
#         Fairy       [304, 464]
#         Fighting    [500, 570]
#         Fire        [360, 550]
#                        ...
# Water   Ice         [475, 535]
#         Poison      [335, 515]
#         Psychic     [315, 520]
#         Rock        [355, 495]
#         Steel       [530, 530]
# Name: Total, Length: 163, dtype: object

# %% [markdown]
# # Multi-level indexing
# In this section, we'll cover some more advanced topics in pandas, including
# *   Multi-indexing
# *   Pivot tables
#
# We'll be introducing some more data to play with, based on state populations over time

# %%
state_populations_url = 'https://raw.githubusercontent.com/jakevdp/data-USstates/master/state-population.csv'
state_abbrevs_url = 'https://raw.githubusercontent.com/jakevdp/data-USstates/master/state-abbrevs.csv'
state_areas_url = 'https://raw.githubusercontent.com/jakevdp/data-USstates/master/state-areas.csv'

state_areas = pd.read_csv(state_areas_url, index_col='state')
state_areas.head() # just print top 5 rows
# Out:
#             area (sq. mi)
# state
# Alabama             52423
# Alaska             656425
# Arizona            114006
# Arkansas            53182
# California         163707

# %%
state_abbrevs = pd.read_csv(state_abbrevs_url)
state_abbrevs.head()
# Out:
#         state abbreviation
# 0     Alabama           AL
# 1      Alaska           AK
# 2     Arizona           AZ
# 3    Arkansas           AR
# 4  California           CA

# %%
state_populations = pd.read_csv(state_populations_url) 
state_populations.head(10) #print first 10 rows
# Out:
#   state/region     ages  year  population
# 0           AL  under18  2012   1117489.0
# 1           AL    total  2012   4817528.0
# 2           AL  under18  2010   1130966.0
# 3           AL    total  2010   4785570.0
# 4           AL  under18  2011   1125763.0
# 5           AL    total  2011   4801627.0
# 6           AL    total  2009   4757938.0
# 7           AL  under18  2009   1134192.0
# 8           AL  under18  2013   1111481.0
# 9           AL    total  2013   4833722.0

# %%
state_populations.tail()
# Out:
#      state/region     ages  year   population
# 2539          USA    total  2010  309326295.0
# 2540          USA  under18  2011   73902222.0
# 2541          USA    total  2011  311582564.0
# 2542          USA  under18  2012   73708179.0
# 2543          USA    total  2012  313873685.0

# %% [markdown]
# Note that the state populations are just listed by abbreviations. It may be useful to include the state names as a column in a table. We have this information in the `state_abbrevs` table. We'd like to merge it with the population data.
#
# The function `pd.merge()` merges two dataframes using set logic.

# %%
merged = pd.merge(state_populations, state_abbrevs, how='outer',
                 left_on='state/region', right_on='abbreviation')
# The arguments left_on and right_on specify what columns to join on. It looks for matching values in each dataframe
# and fills in the additional columns of the merged dataframe based on the matching data
# The 'how' argument specifies what kind of join. Outer means keep all entries even if one does not show up in the other
# conversely, 'inner' discards rows where a corresponding entry does not exist in the other
merged
# Out:
#      state/region     ages  year   population    state abbreviation
# 0              AL  under18  2012    1117489.0  Alabama           AL
# 1              AL    total  2012    4817528.0  Alabama           AL
# 2              AL  under18  2010    1130966.0  Alabama           AL
# 3              AL    total  2010    4785570.0  Alabama           AL
# 4              AL  under18  2011    1125763.0  Alabama           AL
# ...           ...      ...   ...          ...      ...          ...
# 2539          USA    total  2010  309326295.0      NaN          NaN
# 2540          USA  under18  2011   73902222.0      NaN          NaN
# 2541          USA    total  2011  311582564.0      NaN          NaN
# 2542          USA  under18  2012   73708179.0      NaN          NaN
# 2543          USA    total  2012  313873685.0      NaN          NaN
#
# [2544 rows x 6 columns]

# %%
# we can also drop the unnecessary extra abbreviation column now
merged = merged.drop('abbreviation', axis=1) #drop from columns
merged.head()
# Out:
#   state/region     ages  year  population    state
# 0           AL  under18  2012   1117489.0  Alabama
# 1           AL    total  2012   4817528.0  Alabama
# 2           AL  under18  2010   1130966.0  Alabama
# 3           AL    total  2010   4785570.0  Alabama
# 4           AL  under18  2011   1125763.0  Alabama

# %%
# we can check if there were any missing values
merged.isnull().any()
# Out:
# state/region    False
# ages            False
# year            False
# population       True
# state            True
# dtype: bool

# %%
# let's see where the issue is. What entries are missing population entries?
merged.loc[merged['population'].isnull()]
# Out:
#      state/region     ages  year  population state
# 2448           PR  under18  1990         NaN   NaN
# 2449           PR    total  1990         NaN   NaN
# 2450           PR    total  1991         NaN   NaN
# 2451           PR  under18  1991         NaN   NaN
# 2452           PR    total  1993         NaN   NaN
# 2453           PR  under18  1993         NaN   NaN
# 2454           PR  under18  1992         NaN   NaN
# 2455           PR    total  1992         NaN   NaN
# 2456           PR  under18  1994         NaN   NaN
# 2457           PR    total  1994         NaN   NaN
# 2458           PR    total  1995         NaN   NaN
# 2459           PR  under18  1995         NaN   NaN
# 2460           PR  under18  1996         NaN   NaN
# 2461           PR    total  1996         NaN   NaN
# 2462           PR  under18  1998         NaN   NaN
# 2463           PR    total  1998         NaN   NaN
# 2464           PR    total  1997         NaN   NaN
# 2465           PR  under18  1997         NaN   NaN
# 2466           PR    total  1999         NaN   NaN
# 2467           PR  under18  1999         NaN   NaN

# %%
# what about where there's no state entry?
merged.loc[merged['state'].isnull(), 'state/region']
# Out:
# 2448     PR
# 2449     PR
# 2450     PR
# 2451     PR
# 2452     PR
# 2453     PR
# 2454     PR
# 2455     PR
# 2456     PR
# 2457     PR
# 2458     PR
# 2459     PR
# 2460     PR
# 2461     PR
# 2462     PR
# 2463     PR
# 2464     PR
# 2465     PR
# 2466     PR
# 2467     PR
# 2468     PR
# 2469     PR
# 2470     PR
# 2471     PR
# 2472     PR
# 2473     PR
# 2474     PR
# 2475     PR
# 2476     PR
# 2477     PR
# 2478     PR
# 2479     PR
# 2480     PR
# 2481     PR
# 2482     PR
# 2483     PR
# 2484     PR
# 2485     PR
# 2486     PR
# 2487     PR
# 2488     PR
# 2489     PR
# 2490     PR
# 2491     PR
# 2492     PR
# 2493     PR
# 2494     PR
# 2495     PR
# 2496    USA
# 2497    USA
# 2498    USA
# 2499    USA
# 2500    USA
# 2501    USA
# 2502    USA
# 2503    USA
# 2504    USA
# 2505    USA
# 2506    USA
# 2507    USA
# 2508    USA
# 2509    USA
# 2510    USA
# 2511    USA
# 2512    USA
# 2513    USA
# 2514    USA
# 2515    USA
# 2516    USA
# 2517    USA
# 2518    USA
# 2519    USA
# 2520    USA
# 2521    USA
# 2522    USA
# 2523    USA
# 2524    USA
# 2525    USA
# 2526    USA
# 2527    USA
# 2528    USA
# 2529    USA
# 2530    USA
# 2531    USA
# 2532    USA
# 2533    USA
# 2534    USA
# 2535    USA
# 2536    USA
# 2537    USA
# 2538    USA
# 2539    USA
# 2540    USA
# 2541    USA
# 2542    USA
# 2543    USA
# Name: state/region, dtype: object

# %%
# more concicely, we can use .unique() to only see the unique values
merged.loc[merged['state'].isnull(), 'state/region'].unique()
# Out:
# array(['PR', 'USA'], dtype=object)

# %%
# We can fix this easily
merged.loc[merged['state/region'] == 'PR', 'state'] = 'Puerto Rico'
merged.loc[merged['state/region'] == 'USA', 'state'] = 'United States'
merged.isnull().any()
# Out:
# state/region    False
# ages            False
# year            False
# population       True
# state           False
# dtype: bool

# %%
# now let's combine the data with the area data
final = pd.merge(merged, state_areas, on='state', how='left')
final.head()
# Out:
#   state/region     ages  year  population    state  area (sq. mi)
# 0           AL  under18  2012   1117489.0  Alabama        52423.0
# 1           AL    total  2012   4817528.0  Alabama        52423.0
# 2           AL  under18  2010   1130966.0  Alabama        52423.0
# 3           AL    total  2010   4785570.0  Alabama        52423.0
# 4           AL  under18  2011   1125763.0  Alabama        52423.0

# %%
# we can use the .query() syntax to search for specific data
data2010 = final.query("year == 2010 & ages == 'total'") # specify column name 
data2010.set_index('state', inplace=True) # equivalent to data2010 = data2010.set_index('state')
data2010.head()
# Out:
#            state/region   ages  year  population  area (sq. mi)
# state
# Alabama              AL  total  2010   4785570.0        52423.0
# Alaska               AK  total  2010    713868.0       656425.0
# Arizona              AZ  total  2010   6408790.0       114006.0
# Arkansas             AR  total  2010   2922280.0        53182.0
# California           CA  total  2010  37333601.0       163707.0

# %%
# Let's compute the density of each state and then sort by density
density = data2010['population'] / data2010['area (sq. mi)']
density.sort_values(ascending=False, inplace=True)
density
# Out:
# state
# District of Columbia    8898.897059
# Puerto Rico             1058.665149
# New Jersey              1009.253268
# Rhode Island             681.339159
# Connecticut              645.600649
# Massachusetts            621.815538
# Maryland                 466.445797
# Delaware                 460.445752
# New York                 356.094135
# Florida                  286.597129
# Pennsylvania             275.966651
# Ohio                     257.549634
# California               228.051342
# Illinois                 221.687472
# Virginia                 187.622273
# Indiana                  178.197831
# North Carolina           177.617157
# Georgia                  163.409902
# Tennessee                150.825298
# South Carolina           144.854594
# New Hampshire            140.799273
# Hawaii                   124.746707
# Kentucky                 107.586994
# Michigan                 102.015794
# Washington                94.557817
# Texas                     93.987655
# Alabama                   91.287603
# Louisiana                 87.676099
# Wisconsin                 86.851900
# Missouri                  86.015622
# West Virginia             76.519582
# Vermont                   65.085075
# Mississippi               61.321530
# Minnesota                 61.078373
# Arizona                   56.214497
# Arkansas                  54.948667
# Iowa                      54.202751
# Oklahoma                  53.778278
# Colorado                  48.493718
# Oregon                    39.001565
# Maine                     37.509990
# Kansas                    34.745266
# Utah                      32.677188
# Nevada                    24.448796
# Nebraska                  23.654153
# Idaho                     18.794338
# New Mexico                16.982737
# South Dakota              10.583512
# North Dakota               9.537565
# Montana                    6.736171
# Wyoming                    5.768079
# Alaska                     1.087509
# United States                   NaN
# dtype: float64

# %%
density.tail()
# Out:
# state
# North Dakota     9.537565
# Montana          6.736171
# Wyoming          5.768079
# Alaska           1.087509
# United States         NaN
# dtype: float64

# %% [markdown]
# ### Exercises
# Compute the total population of the entire united states, as well as its population density for each year.
#
# Sort the states by population density.
#
# What year saw the biggest change in population for the US as a whole?
#
# Which states had the biggest percentage change in population in that year?

# %%
df_exercise = final.query("ages == 'total' & state != 'United States' & state!= 'Puerto Rico'")
df_exercise
# Out:
#      state/region   ages  year  population    state  area (sq. mi)
# 1              AL  total  2012   4817528.0  Alabama        52423.0
# 3              AL  total  2010   4785570.0  Alabama        52423.0
# 5              AL  total  2011   4801627.0  Alabama        52423.0
# 6              AL  total  2009   4757938.0  Alabama        52423.0
# 9              AL  total  2013   4833722.0  Alabama        52423.0
# ...           ...    ...   ...         ...      ...            ...
# 2439           WY  total  1994    480283.0  Wyoming        97818.0
# 2441           WY  total  1992    466251.0  Wyoming        97818.0
# 2442           WY  total  1993    473081.0  Wyoming        97818.0
# 2444           WY  total  1991    459260.0  Wyoming        97818.0
# 2447           WY  total  1990    453690.0  Wyoming        97818.0
#
# [1224 rows x 6 columns]

# %%
df_exercise1 = df_exercise.groupby('year')[['population','area (sq. mi)']].sum().reset_index()

df_exercise1['population density'] = df_exercise1['population']/df_exercise1['area (sq. mi)']

df_exercise1
# Out:
#     year   population  area (sq. mi)  population density
# 0   1990  249622814.0      3786884.0           65.917734
# 1   1991  252980942.0      3786884.0           66.804513
# 2   1992  256514231.0      3786884.0           67.737546
# 3   1993  259918595.0      3786884.0           68.636535
# 4   1994  263125826.0      3786884.0           69.483466
# 5   1995  266278403.0      3786884.0           70.315965
# 6   1996  269394291.0      3786884.0           71.138776
# 7   1997  272646932.0      3786884.0           71.997698
# 8   1998  275854116.0      3786884.0           72.844617
# 9   1999  279040181.0      3786884.0           73.685959
# 10  2000  282162411.0      3786884.0           74.510445
# 11  2001  284968955.0      3786884.0           75.251567
# 12  2002  287625193.0      3786884.0           75.952998
# 13  2003  290107933.0      3786884.0           76.608614
# 14  2004  292805298.0      3786884.0           77.320905
# 15  2005  295516599.0      3786884.0           78.036876
# 16  2006  298379912.0      3786884.0           78.792990
# 17  2007  301231207.0      3786884.0           79.545929
# 18  2008  304093966.0      3786884.0           80.301896
# 19  2009  306771529.0      3786884.0           81.008959
# 20  2010  309326295.0      3786884.0           81.683594
# 21  2011  311582564.0      3786884.0           82.279405
# 22  2012  313873685.0      3786884.0           82.884420
# 23  2013  316128839.0      3786884.0           83.479937

# %%
df_exercise2 = df_exercise.copy()
df_exercise2['population density'] = df_exercise2['population']/df_exercise2['area (sq. mi)']
df_exercise2
# Out:
#      state/region   ages  year  population    state  area (sq. mi)  \
# 1              AL  total  2012   4817528.0  Alabama        52423.0
# 3              AL  total  2010   4785570.0  Alabama        52423.0
# 5              AL  total  2011   4801627.0  Alabama        52423.0
# 6              AL  total  2009   4757938.0  Alabama        52423.0
# 9              AL  total  2013   4833722.0  Alabama        52423.0
# ...           ...    ...   ...         ...      ...            ...
# 2439           WY  total  1994    480283.0  Wyoming        97818.0
# 2441           WY  total  1992    466251.0  Wyoming        97818.0
# 2442           WY  total  1993    473081.0  Wyoming        97818.0
# 2444           WY  total  1991    459260.0  Wyoming        97818.0
# 2447           WY  total  1990    453690.0  Wyoming        97818.0
#
#       population density
# 1              91.897221
# 3              91.287603
# 5              91.593900
# 6              90.760506
# 9              92.206131
# ...                  ...
# 2439            4.909965
# 2441            4.766515
# 2442            4.836339
# 2444            4.695046
# 2447            4.638103
#
# [1224 rows x 7 columns]

# %%
df_exercise2 = df_exercise2.sort_values(by='population density',ascending=False)
df_exercise2
# Out:
#     state/region   ages  year  population                 state  \
# 391           DC  total  2013    646449.0  District of Columbia
# 385           DC  total  2012    633427.0  District of Columbia
# 387           DC  total  2011    619624.0  District of Columbia
# 431           DC  total  1990    605321.0  District of Columbia
# 389           DC  total  2010    605125.0  District of Columbia
# ..           ...    ...   ...         ...                   ...
# 53            AK  total  1994    603308.0                Alaska
# 56            AK  total  1993    599434.0                Alaska
# 50            AK  total  1992    588736.0                Alaska
# 55            AK  total  1991    570193.0                Alaska
# 48            AK  total  1990    553290.0                Alaska
#
#      area (sq. mi)  population density
# 391           68.0         9506.602941
# 385           68.0         9315.102941
# 387           68.0         9112.117647
# 431           68.0         8901.779412
# 389           68.0         8898.897059
# ..             ...                 ...
# 53        656425.0            0.919081
# 56        656425.0            0.913180
# 50        656425.0            0.896882
# 55        656425.0            0.868634
# 48        656425.0            0.842884
#
# [1224 rows x 7 columns]

# %%
df_exercise3 = df_exercise1.copy()
df_exercise3['population change'] = df_exercise3['population'].diff().abs()
df_exercise3 = df_exercise3.sort_values(by='population change', ascending=False).reset_index()


#np.max(df_exercise3['population change']) this also works
df_exercise3['year'][0]
# Out:
# 1992

# %%
#the year with the highest population change is 1992
df_exercise1992 = df_exercise2.query("year == 1992").copy()
df_exercise1992.head()
# Out:
#      state/region   ages  year  population                 state  \
# 429            DC  total  1992    597567.0  District of Columbia
# 1479           NJ  total  1992   7880508.0            New Jersey
# 1879           RI  total  1992   1012581.0          Rhode Island
# 333            CT  total  1992   3300712.0           Connecticut
# 1017           MA  total  1992   6028709.0         Massachusetts
#
#       area (sq. mi)  population density
# 429            68.0         8787.750000
# 1479         8722.0          903.520752
# 1879         1545.0          655.392233
# 333          5544.0          595.366522
# 1017        10555.0          571.170914

# %%
#we need data from the year before(1991) to calculate the percent change
df_exercise1991 = df_exercise2.query("year == 1991").copy()

df_exercise1991
# Out:
#      state/region   ages  year  population                 state  \
# 426            DC  total  1991    600870.0  District of Columbia
# 1484           NJ  total  1991   7814676.0            New Jersey
# 1874           RI  total  1991   1010649.0          Rhode Island
# 331            CT  total  1991   3302895.0           Connecticut
# 1010           MA  total  1991   6018470.0         Massachusetts
# 1004           MD  total  1991   4867641.0              Maryland
# 340            DE  total  1991    683080.0              Delaware
# 1580           NY  total  1991  18122510.0              New York
# 1868           PA  total  1991  11982164.0          Pennsylvania
# 1682           OH  total  1991  10945762.0                  Ohio
# 435            FL  total  1991  13369798.0               Florida
# 626            IL  total  1991  11568964.0              Illinois
# 234            CA  total  1991  30470736.0            California
# 716            IN  total  1991   5616388.0               Indiana
# 2252           VA  total  1991   6301217.0              Virginia
# 1586           NC  total  1991   6784280.0        North Carolina
# 1394           NH  total  1991   1109929.0         New Hampshire
# 2060           TN  total  1991   4966587.0             Tennessee
# 524            GA  total  1991   6653005.0               Georgia
# 1964           SC  total  1991   3570404.0        South Carolina
# 530            HI  total  1991   1136754.0                Hawaii
# 1100           MI  total  1991   9400446.0              Michigan
# 818            KY  total  1991   3722328.0              Kentucky
# 908            LA  total  1991   4253279.0             Louisiana
# 44             AL  total  1991   4099156.0               Alabama
# 2354           WI  total  1991   4964343.0             Wisconsin
# 2348           WV  total  1991   1798735.0         West Virginia
# 1202           MO  total  1991   5170800.0              Missouri
# 2258           WA  total  1991   5025624.0            Washington
# 2066           TX  total  1991  17398005.0                 Texas
# 2162           VT  total  1991    568606.0               Vermont
# 1196           MS  total  1991   2598733.0           Mississippi
# 1106           MN  total  1991   4440859.0             Minnesota
# 722            IA  total  1991   2797613.0                  Iowa
# 1772           OK  total  1991   3175440.0              Oklahoma
# 46           1932.0        0.191164
# 47          10239.0        0.170126
# 48           1427.0        0.115352
# 49          -2183.0       -0.066094
# 50          -3303.0       -0.549703

# %%
df_exercise4.loc[0:4,'state']
#answer
# Out:
# 0      Nevada
# 1     Arizona
# 2      Alaska
# 3    Colorado
# 4        Utah
# Name: state, dtype: object

# %% [markdown]
# ## Multiindexing
# You can use multiple columns to define an index, as long as each row has a unique combination of values within those columns. In the following example, we will use the columns "state/region", "year", and "ages" of the population dataframe as an index

# %% [markdown]
# We use the `.set_index(['column_name1', 'column_name2, ...])'` command to create a multiindex from existing columns.
#
# Note that many operations require a multiindex to be sorted, so we also call `.sort_index()` on the dataframe. Also, `.set_index()` and `.sort_index()` return a _copy_ of the dataframe, so we assign the output to itself to update the value.

# %%
# set index to use multiple columns
final = final.set_index(['state/region','year','ages']) # overwrite old version with new version with index set
final = final.sort_index() # replace itself with a version with a sorted index
final.tail(10) #print last 10 entries
# Out:
#                            population    state  area (sq. mi)
# state/region year ages
# WY           2009 total      559851.0  Wyoming        97818.0
#                   under18    134960.0  Wyoming        97818.0
#              2010 total      564222.0  Wyoming        97818.0
#                   under18    135351.0  Wyoming        97818.0
#              2011 total      567329.0  Wyoming        97818.0
#                   under18    135407.0  Wyoming        97818.0
#              2012 total      576626.0  Wyoming        97818.0
#                   under18    136526.0  Wyoming        97818.0
#              2013 total      582658.0  Wyoming        97818.0
#                   under18    137679.0  Wyoming        97818.0

# %%
final.loc[('MA',2009,'total'):('WY',2011,'total')]
# Out:
#                            population          state  area (sq. mi)
# state/region year ages
# MA           2009 total     6517613.0  Massachusetts        10555.0
#                   under18   1422935.0  Massachusetts        10555.0
#              2010 total     6563263.0  Massachusetts        10555.0
#                   under18   1415962.0  Massachusetts        10555.0
#              2011 total     6606285.0  Massachusetts        10555.0
# ...                               ...            ...            ...
# WY           2009 total      559851.0        Wyoming        97818.0
#                   under18    134960.0        Wyoming        97818.0
#              2010 total      564222.0        Wyoming        97818.0
#                   under18    135351.0        Wyoming        97818.0
#              2011 total      567329.0        Wyoming        97818.0
#
# [1589 rows x 3 columns]

# %%
"""
Krish: why is multindexing important

Indexes are useful because they provide a unique identifier to each row. This should make sense.
Example of an index is state. But there are mutliple rows for each state. Doesn't work.
So we can combine state, age, and year to create a unique identifier for every row. 
"""

# %% [markdown]
# ### Stacking and unstacking
# Columns can also have multiple levels. In fact, the columns can be thought of as just another index that runs horizontally. This is most easily illustrated by stacking, unstacking, and transposing.
#
# You can convert a level of the row index to a column level using the `.unstack()` command. Conversely, `.stack()` moves a column level to the index

# %%
unstacked = final.unstack(level='ages') # you can unstack by level name; this moves the 'ages' categories into the column index
unstacked
# Out:
#                   population              state          area (sq. mi)  \
# ages                   total   under18    total  under18         total
# state/region year
# AK           1990   553290.0  177502.0   Alaska   Alaska      656425.0
#              1991   570193.0  182180.0   Alaska   Alaska      656425.0
#              1992   588736.0  184878.0   Alaska   Alaska      656425.0
#              1993   599434.0  187190.0   Alaska   Alaska      656425.0
#              1994   603308.0  187439.0   Alaska   Alaska      656425.0
# ...                      ...       ...      ...      ...           ...
# WY           2009   559851.0  134960.0  Wyoming  Wyoming       97818.0
#              2010   564222.0  135351.0  Wyoming  Wyoming       97818.0
#              2011   567329.0  135407.0  Wyoming  Wyoming       97818.0
#              2012   576626.0  136526.0  Wyoming  Wyoming       97818.0
#              2013   582658.0  137679.0  Wyoming  Wyoming       97818.0
#
#
# ages                under18
# state/region year
# AK           1990  656425.0
#              1991  656425.0
#              1992  656425.0
#              1993  656425.0
#              1994  656425.0
# ...                     ...
# WY           2009   97818.0
#              2010   97818.0
#              2011   97818.0
#              2012   97818.0
#              2013   97818.0
#
# [1272 rows x 6 columns]

# %%
restacked = unstacked.stack('ages', dropna=False) # stacks the column level back into the row index
# by default, .stack() omits entries with NaN. If you want to preserve the NaN entries, use the option dropna=False
restacked == final # just like the original state_populations dataframe
# Out:
#                            population  state  area (sq. mi)
# state/region year ages
# AK           1990 total          True   True           True
#                   under18        True   True           True
#              1991 total          True   True           True
#                   under18        True   True           True
#              1992 total          True   True           True
# ...                               ...    ...            ...
# WY           2011 under18        True   True           True
#              2012 total          True   True           True
#                   under18        True   True           True
#              2013 total          True   True           True
#                   under18        True   True           True
#
# [2544 rows x 3 columns]

# %%
final.unstack(level=0) # you can also unstack using integer levels. Here we unstacked level 0, corresponding to state/region
# Out:
#              population                                               \
# state/region         AK         AL         AR         AZ          CA
# year ages
# 1990 total     553290.0  4050055.0  2356586.0  3684097.0  29959515.0
#      under18   177502.0  1050041.0   620933.0  1006040.0   7980501.0
# 1991 total     570193.0  4099156.0  2383144.0  3788576.0  30470736.0
#      under18   182180.0  1060794.0   626212.0  1028285.0   8245605.0
# 1992 total     588736.0  4154014.0  2415984.0  3915740.0  30974659.0
#      under18   184878.0  1072873.0   638269.0  1055572.0   8439647.0
# 1993 total     599434.0  4214202.0  2456303.0  4065440.0  31274928.0
#      under18   187190.0  1085606.0   643474.0  1094233.0   8624810.0
# 1994 total     603308.0  4260229.0  2494019.0  4245089.0  31484435.0
#      under18   187439.0  1097180.0   653842.0  1119857.0   8790058.0
# 1995 total     604412.0  4296800.0  2535399.0  4432499.0  31696582.0
#      under18   184990.0  1110553.0   667671.0  1173391.0   8920578.0
# 1996 total     608569.0  4331103.0  2572109.0  4586940.0  32018834.0
#      under18   185360.0  1112092.0   677912.0  1215285.0   9079519.0
# 1997 total     612968.0  4367935.0  2601091.0  4736990.0  32486010.0
#      under18   188280.0  1122893.0   680203.0  1237159.0   9135359.0
# 1998 total     619933.0  4404701.0  2626289.0  4883342.0  32987675.0
#      under18   192636.0  1118252.0   683637.0  1285794.0   9163238.0
# 1999 total     624779.0  4430141.0  2651860.0  5023823.0  33499204.0
#      under18   191422.0  1121287.0   681940.0  1332396.0   9207878.0
# 2000 total     627963.0  4452173.0  2678588.0  5160586.0  33987977.0
#      under18   190615.0  1122273.0   680378.0  1373414.0   9267089.0
# 2001 total     633714.0  4467634.0  2691571.0  5273477.0  34479458.0
#      under18   188771.0  1120409.0   679606.0  1399015.0   9325466.0
#      under18  42146.0  268601.0 NaN  84904.0  42769.0  9615.0  71303.0
# 2013 total    42146.0  268601.0 NaN  84904.0  42769.0  9615.0  71303.0
#      under18  42146.0  268601.0 NaN  84904.0  42769.0  9615.0  71303.0
#
#
# state/region       WI       WV       WY
# year ages
# 1990 total    65503.0  24231.0  97818.0
#      under18  65503.0  24231.0  97818.0
# 1991 total    65503.0  24231.0  97818.0
#      under18  65503.0  24231.0  97818.0
# 1992 total    65503.0  24231.0  97818.0
#      under18  65503.0  24231.0  97818.0
# 1993 total    65503.0  24231.0  97818.0
#      under18  65503.0  24231.0  97818.0
# 1994 total    65503.0  24231.0  97818.0
#      under18  65503.0  24231.0  97818.0
# 1995 total    65503.0  24231.0  97818.0
#      under18  65503.0  24231.0  97818.0
# 1996 total    65503.0  24231.0  97818.0
#      under18  65503.0  24231.0  97818.0
# 1997 total    65503.0  24231.0  97818.0
#      under18  65503.0  24231.0  97818.0
# 1998 total    65503.0  24231.0  97818.0
#      under18  65503.0  24231.0  97818.0
# 1999 total    65503.0  24231.0  97818.0
#      under18  65503.0  24231.0  97818.0
# 2000 total    65503.0  24231.0  97818.0
#      under18  65503.0  24231.0  97818.0
# 2001 total    65503.0  24231.0  97818.0
#      under18  65503.0  24231.0  97818.0
# 2002 total    65503.0  24231.0  97818.0
#      under18  65503.0  24231.0  97818.0
# 2003 total    65503.0  24231.0  97818.0
#      under18  65503.0  24231.0  97818.0
# 2004 total    65503.0  24231.0  97818.0
#      under18  65503.0  24231.0  97818.0
# 2005 total    65503.0  24231.0  97818.0
#      under18  65503.0  24231.0  97818.0
# 2006 total    65503.0  24231.0  97818.0
#      under18  65503.0  24231.0  97818.0
# 2007 total    65503.0  24231.0  97818.0
#      under18  65503.0  24231.0  97818.0
# 2008 total    65503.0  24231.0  97818.0
#      under18  65503.0  24231.0  97818.0
# 2009 total    65503.0  24231.0  97818.0
#      under18  65503.0  24231.0  97818.0
# 2010 total    65503.0  24231.0  97818.0
#      under18  65503.0  24231.0  97818.0
# 2011 total    65503.0  24231.0  97818.0
#      under18  65503.0  24231.0  97818.0
# 2012 total    65503.0  24231.0  97818.0
#      under18  65503.0  24231.0  97818.0
# 2013 total    65503.0  24231.0  97818.0
#      under18  65503.0  24231.0  97818.0
#
# [48 rows x 159 columns]

# %% [markdown]
# You can switch the row and column index using the transpose function `.T`

# %%
final.unstack(level=0).T

# %% [markdown]
# ### Pivoting
# Pivoting is another advanced way to transform data. It creates a new dataframe using the values of columns as `index` and `column` values.
#
# You can then aggregate using `aggfunc` the elements of another column, which becomes the `values` of this new dataframe.

# %%
# let's create a table which lists all pokemon for given type combinations
pokedex_df.pivot_table(values='Pokemon', # line breaks within parentheses automatically continue onto next line
                       index='Type I', # values of Type I become index entries
                       columns='Type II', # likewise Type II become columns
                       aggfunc=lambda x:", ".join(x)).fillna('') # the lambda function here just joins a list of strings using a comma
                      # we also fill nan values with empty string for aesthetics
# Out:
# Type II                                                      \
# Type I
# Bug       Caterpie, Metapod, Pinsir, Pineco, Wurmple, Si...
# Dark      Umbreon, Poochyena, Mightyena, Absol, Darkrai,...
# Dragon    Dratini, Dragonair, Bagon, Shelgon, Axew, Frax...
# Electric  Pikachu, Raichu, Voltorb, Electrode, Electabuz...
# Fairy     Clefairy, Clefable, Cleffa, Togepi, Snubbull, ...
# Fighting  Mankey, Primeape, Machop, Machoke, Machamp, Hi...
# Fire      Charmander, Charmeleon, Vulpix, Ninetales, Gro...
# Flying                                             Tornadus
# Ghost     Misdreavus, Shuppet, Banette, Duskull, Dusclop...
# Grass     Tangela, Chikorita, Bayleef, Meganium, Belloss...
# Ground    Sandshrew, Sandslash, Diglett, Dugtrio, Cubone...
# Ice       Snorunt, Glalie, Regice, Glaceon, Vanillite, V...
# Normal    Rattata, Raticate, Meowth, Persian, Lickitung,...
# Poison    Ekans, Arbok, Nidoran♀, Nidorina, Nidoran♂, Ni...
# Psychic   Abra, Kadabra, Alakazam, Drowzee, Hypno, Mewtw...
# Rock      Sudowoodo, Nosepass, Regirock, Cranidos, Rampa...
# Steel                    Registeel, Klink, Klang, Klinklang
# Water     Squirtle, Wartortle, Blastoise, Psyduck, Goldu...
#
# Type II                   Bug                                     Dark  \
# Type I
# Bug
# Dark
# Dragon
# Electric
# Fairy
# Fighting                                                       Pangoro
# Fire                                                        Incineroar
# Flying
# Ghost                                                        Spiritomb
# Grass                                       Nuzleaf, Shiftry, Cacturne
# Ground                                   Sandile, Krokorok, Krookodile
# Ice
# Normal
# Poison                Skorupi                Stunky, Skuntank, Drapion
# Psychic                                                      Hoopa (U)
# Rock         Anorith, Armaldo                                Tyranitar
# Steel
# Water     Dewpider, Araquanid  Carvanha, Sharpedo, Crawdaunt, Greninja
#
# Type II                                 Dragon  \
# Type I
# Bug
# Dark      Deino, Zweilous, Hydreigon, Guzzlord
# Dragon
# Electric
# Fairy
# Fighting
# Fire                                Turtonator
# Flying                         Noibat, Noivern
# Ghost                   Giratina, Giratina (O)
# Grass
# Ground                         Vibrava, Flygon
# Ice
# Normal                                  Drampa
# Poison                                Dragalge
# Psychic
# Rock                         Tyrunt, Tyrantrum
# Steel                                   Dialga
# Water                          Kingdra, Palkia
#
# Type II                                  Electric  \
# Type I
# Bug       Joltik, Galvantula, Charjabug, Vikavolt
# Dark
# Dragon                                     Zekrom
# Electric
# Fairy
# Fighting
# Fire
# Flying
# Ghost
# Grass
# Ground                                   Stunfisk
# Ice
# Normal
# Poison
# Psychic
# Rock
# Steel
# Water                           Chinchou, Lanturn
#
# Type II                                               Fairy  \
# Type I
# Bug                                      Cutiefly, Ribombee
# Dark
# Dragon
# Electric                                 Dedenne, Tapu Koko
# Fairy
# Fighting
# Fire
# Flying
# Ghost                                               Mimikyu
# Grass     Cottonee, Whimsicott, Morelull, Shiinotic, Tap...
# Ground
# Ice
# Normal           Jigglypuff, Wigglytuff, Igglybuff, Azurill
# Poison
# Psychic   Mr. Mime, Ralts, Kirlia, Gardevoir, Mime Jr., ...
# Rock                                       Carbink, Diancie
# Steel                              Mawile, Klefki, Magearna
# Water               Marill, Azumarill, Primarina, Tapu Fini
#
# Type II                                            Fighting  \
# Type I
# Bug                          Heracross, Buzzwole, Pheromosa
# Dark                                       Scraggy, Scrafty
# Dragon                                    Hakamo-o, Kommo-o
# Electric
# Fairy
# Fighting
# Fire      Combusken, Blaziken, Monferno, Infernape, Pign...
# Flying
# Ghost
# Grass                         Breloom, Virizion, Chesnaught
# Ground
# Ice
# Normal                        Meloetta (P), Stufful, Bewear
# Poison                                  Croagunk, Toxicroak
# Psychic                                             Gallade
# Rock                                              Terrakion
# Steel                                              Cobalion
# Water                                     Poliwrath, Keldeo
#
# Type II                           Fire  \
# Type I
# Bug                Larvesta, Volcarona
# Dark                Houndour, Houndoom
# Dragon                        Reshiram
# Electric                  Rotom (Heat)
# Fairy
# Fighting
# Fire
# Flying
# Ghost     Litwick, Lampent, Chandelure
# Grass
# Ground
# Ice
# Normal
# Poison              Salandit, Salazzle
# Psychic                        Victini
# Rock
# Steel
# Water
#
# Type II                                              Flying  \
# Type I
# Bug       Butterfree, Scyther, Ledyba, Ledian, Yanma, Be...
# Dark        Murkrow, Honchkrow, Vullaby, Mandibuzz, Yveltal
# Dragon              Dragonite, Altaria, Salamence, Rayquaza
# Electric            Zapdos, Rotom (Spin), Emolga, Thundurus
# Fairy                                     Togetic, Togekiss
# Fighting                                           Hawlucha
# Fire      Charizard, Moltres, Ho-oh, Fletchinder, Talonf...
# Flying
# Ghost                                    Drifloon, Drifblim
# Grass     Hoppip, Skiploom, Jumpluff, Tropius, Shaymin (...
# Ground                            Gligar, Gliscor, Landorus
# Ice                                      Articuno, Delibird
# Normal    Pidgey, Pidgeotto, Pidgeot, Spearow, Fearow, F...
# Poison                                Zubat, Golbat, Crobat
# Psychic        Natu, Xatu, Lugia, Woobat, Swoobat, Sigilyph
# Rock      Aerodactyl, Archen, Archeops, Minior (meteor),...
# Steel                                  Skarmory, Celesteela
# Water     Gyarados, Mantine, Wingull, Pelipper, Mantyke,...
#
# Type II                          Ghost  \
# Type I
# Bug                           Shedinja
# Dark                           Sableye
# Dragon
# Electric                         Rotom
# Fairy
# Fighting                     Marshadow
# Fire
# Flying
# Ghost
# Grass                        Decidueye
# Ground                  Golett, Golurk
# Ice                           Froslass
# Normal
# Poison
# Psychic              Hoopa (C), Lunala
# Rock
# Steel     Honedge, Doublade, Aegislash
# Water              Frillish, Jellicent
#
# Type II                                               Grass  \
# Type I
# Bug       Paras, Parasect, Wormadam (P), Sewaddle, Swadl...
# Dark
# Dragon
# Electric                                        Rotom (Cut)
# Fairy
# Fighting
# Fire
# Flying
# Ghost     Phantump, Trevenant, Pumpkaboo, Gourgeist, Dhe...
# Grass
# Ground
# Ice                                       Snover, Abomasnow
# Normal                                   Deerling, Sawsbuck
# Poison
# Psychic                                              Celebi
# Rock                                        Lileep, Cradily
# Steel
# Water                               Lotad, Lombre, Ludicolo
#
# Type II                                              Ground  \
# Type I
# Bug                                   Nincada, Wormadam (S)
# Dark
# Dragon                     Gible, Gabite, Garchomp, Zygarde
# Electric
# Fairy
# Fighting
# Fire                                        Numel, Camerupt
# Flying
# Ghost                                  Sandygast, Palossand
# Grass                                              Torterra
# Ground
# Ice                            Swinub, Piloswine, Mamoswine
# Normal                                            Diggersby
# Poison                                  Nidoqueen, Nidoking
# Psychic
# Rock      Geodude, Graveler, Golem, Onix, Larvitar, Pupitar
# Steel                                               Steelix
# Water     Wooper, Quagsire, Marshtomp, Swampert, Barboac...
#
# Type II                         Ice                 Normal  \
# Type I
# Bug
# Dark               Sneasel, Weavile
# Dragon                       Kyurem
# Electric              Rotom (Frost)  Helioptile, Heliolisk
# Fairy
# Fighting               Crabominable
# Fire                                        Litleo, Pyroar
# Flying
# Ghost
# Grass
# Ground
# Ice
# Normal
# Poison
# Psychic
# Rock                Amaura, Aurorus
# Steel
# Water     Dewgong, Cloyster, Lapras
#
# Type II                                              Poison  \
# Type I
# Bug       Weedle, Kakuna, Beedrill, Venonat, Venomoth, S...
# Dark
# Dragon
# Electric
# Fairy
# Fighting
# Fire
# Flying
# Ghost                               Gastly, Haunter, Gengar
# Grass     Bulbasaur, Ivysaur, Venusaur, Oddish, Gloom, V...
# Ground
# Ice
# Normal
# Poison
# Psychic
# Rock                                               Nihilego
# Steel
# Water                       Tentacool, Tentacruel, Qwilfish
#
# Type II                                             Psychic  \
# Type I
# Bug
# Dark                                         Inkay, Malamar
# Dragon                                       Latias, Latios
# Electric
# Fairy
# Fighting                                 Meditite, Medicham
# Fire                                Darmanitan (Z), Delphox
# Flying
# Ghost
# Grass                                  Exeggcute, Exeggutor
# Ground                                      Baltoy, Claydol
# Ice                                          Jynx, Smoochum
# Normal                    Girafarig, Meloetta (A), Oranguru
# Poison
# Psychic
# Rock                                      Lunatone, Solrock
# Steel     Beldum, Metang, Metagross, Jirachi, Bronzor, B...
# Water         Slowpoke, Slowbro, Starmie, Slowking, Bruxish
#
# Type II                                       Rock  \
# Type I
# Bug                      Shuckle, Dwebble, Crustle
# Dark
# Dragon
# Electric
# Fairy
# Fighting
# Fire                                      Magcargo
# Flying
# Ghost
# Grass
# Ground                  Rhyhorn, Rhydon, Rhyperior
# Ice
# Normal
# Poison
# Psychic
# Rock
# Steel                         Aron, Lairon, Aggron
# Water     Corsola, Relicanth, Tirtouga, Carracosta
#
# Type II                                               Steel  \
# Type I
# Bug       Forretress, Scizor, Wormadam (T), Escavalier, ...
# Dark                                      Pawniard, Bisharp
# Dragon
# Electric         Magnemite, Magneton, Magnezone, Togedemaru
# Fairy
# Fighting                                            Lucario
# Fire                                                Heatran
# Flying
# Ghost
# Grass                        Ferroseed, Ferrothorn, Kartana
# Ground                                            Excadrill
# Ice
# Normal
# Poison
# Psychic                                            Solgaleo
# Rock                         Shieldon, Bastiodon, Probopass
# Steel
# Water                                              Empoleon
#
# Type II                                               Water
# Type I
# Bug                              Surskit, Wimpod, Golisopod
# Dark
# Dragon
# Electric                                       Rotom (Wash)
# Fairy
# Fighting
# Fire                                              Volcanion
# Flying
# Ghost
# Grass
# Ground
# Ice                                 Spheal, Sealeo, Walrein
# Normal                                              Bibarel
# Poison                            Skrelp, Mareanie, Toxapex
# Psychic
# Rock      Omanyte, Omastar, Kabuto, Kabutops, Binacle, B...
# Steel
# Water

# %%
# table comparing the attack and defense of pokemon. Bottom right is the strongest.
pokedex_df.pivot_table(values='Pokemon', # line breaks within parentheses automatically continue onto next line
                       index='Atk', # values of Type I become index entries
                       columns='Def', # likewise Type II become columns
                       aggfunc=lambda x:", ".join(x)).fillna('')# the lambda function here just joins a list of strings using a comma
                      # we also fill nan values with empty string for aesthetics
# Out:
# Def               5        10    15                 20  23  25  28      30   \
# Atk
# 5    Chansey, Happiny
# 10                     Blissey
# 15                                               Feebas
# 20                              Abra  Wishiwashi (solo)              Ledyba
# 22
# ..                ...      ...   ...                ...  ..  ..  ..     ...
# 150
# 160
# 165
# 180                                          Deoxys (A)
# 181
#
# Def 31  32  33  34        35  37  38  39       40  41  42  43  44  45  47   \
# Atk
# 5
# 10
# 15
# 20                   Smeargle              Azurill
# 22
# ..   ..  ..  ..  ..       ...  ..  ..  ..      ...  ..  ..  ..  ..  ..  ..
# 150
# 160
# 165
# 180
# 181
#
# Def 48  49   ... 112 115 116 118 119     120 121 122 125 129 130      131 133  \
# Atk          ...
# 5            ...
# 10           ...
# 15           ...
# 20           ...
# 22           ...
# ..   ..  ..  ...  ..  ..  ..  ..  ..     ...  ..  ..  ..  ..  ..      ...  ..
# 150          ...                      Zekrom
# 160          ...
# 165          ...
# 180          ...
# 181          ...                                                  Kartana
#
# Def 135 139      140 145 150 152 160 168 180 184 200      230
# Atk
# 5
# 10                                                    Shuckle
# 15
# 20
# 22
# ..   ..  ..      ...  ..  ..  ..  ..  ..  ..  ..  ..      ...
# 150          Groudon
# 160
# 165
# 180
# 181
#
# [108 rows x 104 columns]

# %%
# compute the average stats for each type combination
pokedex_df.unstack()
pokedex_df.pivot_table(values='Total',
                       index='Type I', 
                       columns='Type II', 
                       aggfunc=lambda x: np.mean(x)).fillna('')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[98], line 2
#       1 # compute the average stats for each type combination
# ----> 2 pokedex_df.unstack()
#       3 pokedex_df.pivot_table(values='Total',
#       4                        index='Type I',
#       5                        columns='Type II',
#       6                        aggfunc=lambda x: np.mean(x)).fillna('')
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/frame.py:9625, in DataFrame.unstack(self, level, fill_value, sort)
#    9561 """
#    9562 Pivot a level of the (necessarily hierarchical) index labels.
#    9563
#    (...)
#    9621 dtype: float64
#    9622 """
#    9623 from pandas.core.reshape.reshape import unstack
# -> 9625 result = unstack(self, level, fill_value, sort)
#    9627 return result.__finalize__(self, method="unstack")
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/reshape/reshape.py:506, in unstack(obj, level, fill_value, sort)
#     504         return _unstack_frame(obj, level, fill_value=fill_value, sort=sort)
#     505     else:
# --> 506         return obj.T.stack(future_stack=True)
#     507 elif not isinstance(obj.index, MultiIndex):
#     508     # GH 36113
#     509     # Give nicer error messages when unstack a Series whose
#     510     # Index is not a MultiIndex.
#     511     raise ValueError(
#     512         f"index must be a MultiIndex to unstack, {type(obj.index)} was passed"
#     513     )
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/frame.py:9428, in DataFrame.stack(self, level, dropna, sort, future_stack)
#    9426         level = [level]
#    9427     level = [self.columns._get_level_number(lev) for lev in level]
# -> 9428     result = stack_v3(self, level)
#    9430 return result.__finalize__(self, method="stack")
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/reshape/reshape.py:887, in stack_v3(frame, level)
#     885 def stack_v3(frame: DataFrame, level: list[int]) -> Series | DataFrame:
#     886     if frame.columns.nunique() != len(frame.columns):
# --> 887         raise ValueError("Columns with duplicate values are not supported in stack")
#     889     # If we need to drop `level` from columns, it needs to be in descending order
#     890     drop_levnums = sorted(level, reverse=True)
#
# ValueError: Columns with duplicate values are not supported in stack

# %%
# You can compute multiple aggregations on multiple columns by passing a dict
# into the aggfunc argument: aggfunc={'column_name':[list_of_function_names]}
# Note that in this case, the 'value' argument is ignored
pokedex_df.pivot_table(index='Type I', 
                       columns='Type II', 
                       aggfunc={'Total':[lambda x: np.mean(x),lambda x: np.std(x)], 
                                'Atk':[lambda x: np.mean(x),lambda x: np.std(x)]}).fillna('')

# %% [markdown]
# # Exercise
# Using this data (or any other data you're interested in and you find online), put together an analysis using pandas that investigates an interesting question.
#
# It can be serious or silly. Like "Do states with higher population density tend to vote democratic?" (you'd need to pull additional data for this) or "Do pokemon whose names start with the letter D have better stats than those who start with F?"
#
# We'll ask some volunteers to present their analysis at the end

# %%
df_player_stats = pd.read_csv('Player Per Game.csv',index_col='seas_id')
df_player_stats['x3p_total'] = df_player_stats['x3p_per_game']*df_player_stats['g']
df_player_stats['x3pa_total'] = df_player_stats['x3pa_per_game']*df_player_stats['g']
df_player_stats.head()
# Out:
#          season  player_id         player  birth_year pos   age  experience  \
# seas_id
# 31136      2024       5025     A.J. Green         NaN  SG  24.0           2
# 31137      2024       5026    A.J. Lawson         NaN  SG  23.0           2
# 31138      2024       5027     AJ Griffin         NaN  SF  20.0           2
# 31139      2024       4219   Aaron Gordon         NaN  PF  28.0          10
# 31140      2024       4582  Aaron Holiday         NaN  PG  27.0           6
#
#           lg   tm   g    gs  mp_per_game  fg_per_game  fga_per_game  \
# seas_id
# 31136    NBA  MIL  56   0.0         11.0          1.5           3.5
# 31137    NBA  DAL  42   0.0          7.4          1.3           2.9
# 31138    NBA  ATL  20   0.0          8.6          0.9           3.1
# 31139    NBA  DEN  73  73.0         31.5          5.5           9.8
# 31140    NBA  HOU  78   1.0         16.3          2.4           5.3
#
#          fg_percent  x3p_per_game  x3pa_per_game  x3p_percent  x2p_per_game  \
# seas_id
# 31136         0.423           1.2            3.0        0.408           0.3
# 31137         0.446           0.3            1.2        0.260           1.0
# 31138         0.290           0.5            2.0        0.256           0.4
# 31139         0.556           0.5            1.9        0.290           4.9
# 31140         0.446           1.1            2.8        0.387           1.3
#
#          x2pa_per_game  x2p_percent  e_fg_percent  ft_per_game  fta_per_game  \
# seas_id
# 31136              0.5        0.519         0.599          0.3           0.3
# 31137              1.7        0.577         0.500          0.4           0.5
# 31138              1.2        0.348         0.371          0.1           0.1
# 31139              7.9        0.619         0.584          2.4           3.7
# 31140              2.6        0.510         0.547          0.7           0.8
#
#          ft_percent  orb_per_game  drb_per_game  trb_per_game  ast_per_game  \
# seas_id
# 31136         0.895           0.2           1.0           1.1           0.5
# 31137         0.652           0.3           0.9           1.2           0.5
# 31138         1.000           0.1           0.8           0.9           0.3
# 31139         0.658           2.4           4.1           6.5           3.5
# 31140         0.921           0.3           1.3           1.6           1.8
#
#          stl_per_game  blk_per_game  tov_per_game  pf_per_game  pts_per_game  \
# seas_id
# 31136             0.2           0.1           0.2          0.9           4.5
# 31137             0.2           0.1           0.3          0.5           3.2
# 31138             0.1           0.1           0.4          0.3           2.4
# 31139             0.8           0.6           1.4          1.9          13.9
# 31140             0.5           0.1           0.7          1.6           6.6
#
#          x3p_total  x3pa_total
# seas_id
# 31136         67.2       168.0
# 31137         12.6        50.4
# 31138         10.0        40.0
# 31139         36.5       138.7
# 31140         85.8       218.4

# %%
len(df_player_stats)
# Out:
# 31870

# %%
df_player_stats_3p = df_player_stats[['season','player','x3p_total','x3pa_total']]

df_player_stats_3p.head()
# Out:
#          season         player  x3p_total  x3pa_total
# seas_id
# 31136      2024     A.J. Green       67.2       168.0
# 31137      2024    A.J. Lawson       12.6        50.4
# 31138      2024     AJ Griffin       10.0        40.0
# 31139      2024   Aaron Gordon       36.5       138.7
# 31140      2024  Aaron Holiday       85.8       218.4

# %%
df_player_stats_3p.groupby('season')[['x3p_total','x3pa_total']].sum().head(10)
# Out:
#         x3p_total  x3pa_total
# season
# 1947          0.0         0.0
# 1948          0.0         0.0
# 1949          0.0         0.0
# 1950          0.0         0.0
# 1951          0.0         0.0
# 1952          0.0         0.0
# 1953          0.0         0.0
# 1954          0.0         0.0
# 1955          0.0         0.0
# 1956          0.0         0.0

# %%
#the nba 3 point line was added in 1979, which is why there are a lot of 0 attempt rows.
#Filtering data to only the years 1979 and beyond.

df_player_stats_3p = df_player_stats_3p.query('season >= 1979')

# %%
df_player_stats_3p1 = df_player_stats_3p.groupby('season')[['x3p_total','x3pa_total']].sum()

df_player_stats_3p1
# Out:
#         x3p_total  x3pa_total
# season
# 1979          0.0         0.0
# 1980       1513.1      5431.4
# 1981        912.8      4059.0
# 1982       1116.9      4537.7
# 1983       1022.9      4534.3
# 1984       1053.0      4593.2
# 1985       1669.9      5939.4
# 1986       1782.3      6627.9
# 1987       2742.8      9127.4
# 1988       3362.2     10682.0
# 1989       4598.0     14470.0
# 1990       4973.9     15368.4
# 1991       5314.7     16591.5
# 1992       5727.0     17413.7
# 1993       6762.6     20397.8
# 1994       7589.1     22992.5
# 1995      12740.1     35861.8
# 1996      15109.4     41505.6
# 1997      15727.4     43935.7
# 1998      11645.4     33957.9
# 1999       6878.5     20214.1
# 2000      11870.0     33770.6
# 2001      12092.1     34230.6
# 2002      13161.8     37500.8
# 2003      12894.2     37112.6
# 2004      13785.3     39704.2
# 2005      15636.4     43870.3
# 2006      15321.5     42870.5
# 2007      15850.0     44252.5
