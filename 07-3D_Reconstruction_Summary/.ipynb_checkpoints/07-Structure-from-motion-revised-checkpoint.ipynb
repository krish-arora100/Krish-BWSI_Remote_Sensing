# %%
# %%bash
# source /opt/conda/bin/activate opensfm
# mamba install -y 'numpy>=1.19,<2.0.0'
# export PATH=$PATH:/opt/utils/OpenSfM/bin
# # Take initial guess of intrinsic parameters through metadata
# opensfm extract_metadata directory/
#
# # Detect features points
# opensfm detect_features directory/
#
# # Match feature points across images
# opensfm match_features directory/
#
# # This creates "tracks" for the features. That is to say, if a feature in image 1 is matched with one in image 2,
# # and in turn that one is matched with one in image 3, then it links the matches between 1 and 3. In this case,
# # it does not matter since we only have two images
# opensfm create_tracks directory/
#
# # Calculates the essential matrix, the camera pose and the reconstructed feature points
# opensfm reconstruct directory/
#
# # For visualization using Open3D
# opensfm export_ply directory/
# Out:
# Transaction
#
#   Prefix: /opt/conda/envs/opensfm
#
#   Updating specs:
#
#    - numpy[version='>=1.19,<2.0.0']
#    - ca-certificates
#    - openssl
#
#
#   Package             Version  Build                Channel           Size
# ────────────────────────────────────────────────────────────────────────────
#   Install:
# ────────────────────────────────────────────────────────────────────────────
#
#   + libstdcxx-ng       14.1.0  hc0a3c3a_0           conda-forge     Cached
#   + python_abi           3.10  4_cp310              conda-forge        6kB
#   + libgfortran5       14.1.0  hc5f4f2c_0           conda-forge     Cached
#   + libgfortran-ng     14.1.0  h69a702a_0           conda-forge     Cached
#   + libopenblas        0.3.27  pthreads_hac2b453_1  conda-forge        6MB
#   + libblas             3.9.0  23_linux64_openblas  conda-forge       15kB
#   + libcblas            3.9.0  23_linux64_openblas  conda-forge       15kB
#   + liblapack           3.9.0  23_linux64_openblas  conda-forge       15kB
#   + numpy              1.26.4  py310hb13e2d6_0      conda-forge        7MB
#
#   Change:
# ────────────────────────────────────────────────────────────────────────────
#
#   - openssl             3.3.1  h4ab18f5_1           conda-forge     Cached
#   + openssl             3.3.1  h4bc722e_2           conda-forge        3MB
#
#   Upgrade:
# ────────────────────────────────────────────────────────────────────────────
#
#   - ca-certificates  2024.6.2  hbcca054_0           conda-forge     Cached
#   + ca-certificates  2024.7.4  hbcca054_0           conda-forge      155kB
#
#   Summary:
#
#   Install: 9 packages
#   Change: 1 packages
#   Upgrade: 1 packages
#
#   Total download: 16MB
#
# ────────────────────────────────────────────────────────────────────────────
#
#
#
# Looking for: ["numpy[version='>=1.19,<2.0.0']"]
#
#
# Pinned packages:
#   - python 3.10.*
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# warning  libmamba Cache file "/opt/conda/pkgs/cache/497deca9.json" was modified by another program
# warning  libmamba Cache file "/opt/conda/pkgs/cache/09cdf8bf.json" was modified by another program
# 2024-07-28 17:59:54,569 INFO: Extracting EXIF for kitchen08.jpg
# 2024-07-28 17:59:54,656 INFO: Extracting EXIF for kitchen05.jpg
# 2024-07-28 17:59:54,714 INFO: Extracting EXIF for kitchen11.jpg
# 2024-07-28 17:59:54,782 INFO: Extracting EXIF for kitchen01.jpg
# 2024-07-28 17:59:54,837 INFO: Extracting EXIF for kitchen10.jpg
# 2024-07-28 17:59:54,899 INFO: Extracting EXIF for kitchen09.jpg
# 2024-07-28 17:59:54,975 INFO: Extracting EXIF for kitchen12.jpg
# 2024-07-28 17:59:55,033 INFO: Extracting EXIF for kitchen06.jpg
# 2024-07-28 17:59:55,087 INFO: Extracting EXIF for kitchen03.jpg
# 2024-07-28 17:59:55,136 INFO: Extracting EXIF for kitchen07.jpg
# 2024-07-28 17:59:55,184 INFO: Extracting EXIF for kitchen02.jpg
# 2024-07-28 17:59:55,243 INFO: Extracting EXIF for kitchen04.jpg
# 2024-07-28 17:59:56,994 INFO: Planning to use 12759.300000000001 MB of RAM for both processing queue and parallel processing.
# 2024-07-28 17:59:56,995 INFO: Scale-space expected size of a single image : 95.625 MB
# 2024-07-28 17:59:56,995 INFO: Expecting to queue at most 137 images while parallel processing of 1 images.
# 2024-07-28 17:59:56,995 INFO: Reading data for image kitchen08.jpg (queue-size=0)
# 2024-07-28 17:59:57,277 INFO: Finished reading images
# 2024-07-28 17:59:57,277 INFO: Extracting ROOT_HAHOG features for image kitchen08.jpg
# 2024-07-28 17:59:59,345 DEBUG: Found 4976 points in 2.0030434131622314s
# 2024-07-28 17:59:59,346 DEBUG: No segmentation for kitchen08.jpg, no features masked.
# 2024-07-28 17:59:59,392 INFO: Reading data for image kitchen05.jpg (queue-size=0)
# 2024-07-28 17:59:59,661 INFO: Finished reading images
# 2024-07-28 17:59:59,661 INFO: Extracting ROOT_HAHOG features for image kitchen05.jpg
# 2024-07-28 18:00:01,724 DEBUG: Found 4989 points in 2.000156879425049s
# 2024-07-28 18:00:01,725 DEBUG: No segmentation for kitchen05.jpg, no features masked.
# 2024-07-28 18:00:01,770 INFO: Reading data for image kitchen11.jpg (queue-size=0)
# 2024-07-28 18:00:02,015 INFO: Finished reading images
# 2024-07-28 18:00:02,016 INFO: Extracting ROOT_HAHOG features for image kitchen11.jpg
# 2024-07-28 18:00:03,997 DEBUG: Found 4958 points in 1.9240052700042725s
# 2024-07-28 18:00:03,998 DEBUG: No segmentation for kitchen11.jpg, no features masked.
# 2024-07-28 18:00:04,042 INFO: Reading data for image kitchen01.jpg (queue-size=0)
# 2024-07-28 18:00:04,279 INFO: Finished reading images
# 2024-07-28 18:00:04,280 INFO: Extracting ROOT_HAHOG features for image kitchen01.jpg
# 2024-07-28 18:00:06,305 DEBUG: Found 4997 points in 1.9686110019683838s
# 2024-07-28 18:00:06,306 DEBUG: No segmentation for kitchen01.jpg, no features masked.
# 2024-07-28 18:00:06,354 INFO: Reading data for image kitchen10.jpg (queue-size=0)
# 2024-07-28 18:00:06,605 INFO: Finished reading images
# 2024-07-28 18:00:06,605 INFO: Extracting ROOT_HAHOG features for image kitchen10.jpg
# 2024-07-28 18:00:08,583 DEBUG: Found 4827 points in 1.8997573852539062s
# 2024-07-28 18:00:08,584 DEBUG: No segmentation for kitchen10.jpg, no features masked.
# 2024-07-28 18:00:08,628 INFO: Reading data for image kitchen09.jpg (queue-size=0)
# 2024-07-28 18:00:08,878 INFO: Finished reading images
# 2024-07-28 18:00:08,878 INFO: Extracting ROOT_HAHOG features for image kitchen09.jpg
# 2024-07-28 18:00:10,810 DEBUG: Found 4962 points in 1.8745830059051514s
# 2024-07-28 18:00:10,811 DEBUG: No segmentation for kitchen09.jpg, no features masked.
# 2024-07-28 18:00:10,854 INFO: Reading data for image kitchen12.jpg (queue-size=0)
# 2024-07-28 18:00:11,129 INFO: Finished reading images
# 2024-07-28 18:00:11,129 INFO: Extracting ROOT_HAHOG features for image kitchen12.jpg
# 2024-07-28 18:00:13,181 DEBUG: Found 5037 points in 1.9898874759674072s
# 2024-07-28 18:00:13,181 DEBUG: No segmentation for kitchen12.jpg, no features masked.
# 2024-07-28 18:00:13,227 INFO: Reading data for image kitchen06.jpg (queue-size=0)
# 2024-07-28 18:00:13,498 INFO: Finished reading images
# 2024-07-28 18:00:13,498 INFO: Extracting ROOT_HAHOG features for image kitchen06.jpg
# 2024-07-28 18:00:15,547 DEBUG: Found 4976 points in 1.9879236221313477s
# 2024-07-28 18:00:15,548 DEBUG: No segmentation for kitchen06.jpg, no features masked.
# 2024-07-28 18:00:15,592 INFO: Reading data for image kitchen03.jpg (queue-size=0)
# 2024-07-28 18:00:15,862 INFO: Finished reading images
# 2024-07-28 18:00:15,863 INFO: Extracting ROOT_HAHOG features for image kitchen03.jpg
# 2024-07-28 18:00:17,892 DEBUG: Found 4990 points in 1.9729344844818115s
# 2024-07-28 18:00:17,893 DEBUG: No segmentation for kitchen03.jpg, no features masked.
# 2024-07-28 18:00:17,937 INFO: Reading data for image kitchen07.jpg (queue-size=0)
# 2024-07-28 18:00:18,210 INFO: Finished reading images
# 2024-07-28 18:00:18,210 INFO: Extracting ROOT_HAHOG features for image kitchen07.jpg
# 2024-07-28 18:00:20,274 DEBUG: Found 5030 points in 2.00285005569458s
# 2024-07-28 18:00:20,275 DEBUG: No segmentation for kitchen07.jpg, no features masked.
# 2024-07-28 18:00:20,320 INFO: Reading data for image kitchen02.jpg (queue-size=0)
# 2024-07-28 18:00:20,591 INFO: Finished reading images
# 2024-07-28 18:00:20,592 INFO: Extracting ROOT_HAHOG features for image kitchen02.jpg
# 2024-07-28 18:00:22,525 DEBUG: Found 4975 points in 1.8713924884796143s
# 2024-07-28 18:00:22,526 DEBUG: No segmentation for kitchen02.jpg, no features masked.
# 2024-07-28 18:00:22,570 INFO: Reading data for image kitchen04.jpg (queue-size=0)
# 2024-07-28 18:00:22,836 INFO: Finished reading images
# 2024-07-28 18:00:22,836 INFO: Extracting ROOT_HAHOG features for image kitchen04.jpg
# 2024-07-28 18:00:24,820 DEBUG: Found 4896 points in 1.9256319999694824s
# 2024-07-28 18:00:24,821 DEBUG: No segmentation for kitchen04.jpg, no features masked.
# 2024-07-28 18:00:26,502 INFO: Matching 66 image pairs
# 2024-07-28 18:00:26,507 INFO: Computing pair matching with 1 processes
# 2024-07-28 18:00:26,520 DEBUG: No segmentation for kitchen12.jpg, no features masked.
# 2024-07-28 18:00:26,532 DEBUG: No segmentation for kitchen06.jpg, no features masked.
# 2024-07-28 18:00:27,073 DEBUG: Matching kitchen12.jpg and kitchen06.jpg.  Matcher: FLANN (symmetric) T-desc: 0.542 T-robust: 0.022 T-total: 0.565 Matches: 56 Robust: 28 Success: True
# 2024-07-28 18:00:27,083 DEBUG: No segmentation for kitchen10.jpg, no features masked.
# 2024-07-28 18:00:27,416 DEBUG: Matching kitchen12.jpg and kitchen10.jpg.  Matcher: FLANN (symmetric) T-desc: 0.341 T-robust: 0.002 T-total: 0.343 Matches: 443 Robust: 384 Success: True
# 2024-07-28 18:00:27,427 DEBUG: No segmentation for kitchen03.jpg, no features masked.
# 2024-07-28 18:00:27,784 DEBUG: Matching kitchen12.jpg and kitchen03.jpg.  Matcher: FLANN (symmetric) T-desc: 0.348 T-robust: 0.019 T-total: 0.367 Matches: 43 Robust: 17 Success: False
# 2024-07-28 18:00:27,794 DEBUG: No segmentation for kitchen09.jpg, no features masked.
# 2024-07-28 18:00:27,806 DEBUG: No segmentation for kitchen07.jpg, no features masked.
# 2024-07-28 18:00:28,331 DEBUG: Matching kitchen09.jpg and kitchen07.jpg.  Matcher: FLANN (symmetric) T-desc: 0.528 T-robust: 0.019 T-total: 0.547 Matches: 42 Robust: 16 Success: False
# 2024-07-28 18:00:28,342 DEBUG: No segmentation for kitchen01.jpg, no features masked.
# 2024-07-28 18:00:28,354 DEBUG: No segmentation for kitchen02.jpg, no features masked.
# 2024-07-28 18:00:28,876 DEBUG: Matching kitchen01.jpg and kitchen02.jpg.  Matcher: FLANN (symmetric) T-desc: 0.537 T-robust: 0.005 T-total: 0.545 Matches: 2144 Robust: 2045 Success: True
# 2024-07-28 18:00:29,059 DEBUG: Matching kitchen02.jpg and kitchen10.jpg.  Matcher: FLANN (symmetric) T-desc: 0.163 T-robust: 0.019 T-total: 0.182 Matches: 26 Robust: 13 Success: False
# 2024-07-28 18:00:29,070 DEBUG: No segmentation for kitchen04.jpg, no features masked.
# 2024-07-28 18:00:29,081 DEBUG: No segmentation for kitchen11.jpg, no features masked.
# 2024-07-28 18:00:29,594 DEBUG: Matching kitchen04.jpg and kitchen11.jpg.  Matcher: FLANN (symmetric) T-desc: 0.533 T-robust: 0.002 T-total: 0.535 Matches: 145 Robust: 107 Success: True
# 2024-07-28 18:00:29,783 DEBUG: Matching kitchen07.jpg and kitchen04.jpg.  Matcher: FLANN (symmetric) T-desc: 0.170 T-robust: 0.019 T-total: 0.189 Matches: 30 Robust: 11 Success: False
# 2024-07-28 18:00:29,953 DEBUG: Matching kitchen09.jpg and kitchen11.jpg.  Matcher: FLANN (symmetric) T-desc: 0.168 T-robust: 0.001 T-total: 0.169 Matches: 315 Robust: 284 Success: True
# 2024-07-28 18:00:30,121 DEBUG: Matching kitchen03.jpg and kitchen09.jpg.  Matcher: FLANN (symmetric) T-desc: 0.168 Matches: FAILED
# 2024-07-28 18:00:30,132 DEBUG: No segmentation for kitchen05.jpg, no features masked.
# 2024-07-28 18:00:30,145 DEBUG: No segmentation for kitchen08.jpg, no features masked.
# 2024-07-28 18:00:30,662 DEBUG: Matching kitchen05.jpg and kitchen08.jpg.  Matcher: FLANN (symmetric) T-desc: 0.539 T-robust: 0.001 T-total: 0.541 Matches: 188 Robust: 154 Success: True
# 2024-07-28 18:00:44,955 INFO: Two-view 5-points reconstruction inliers (transposed=False): 1486 / 1499
# 2024-07-28 18:00:44,985 INFO: Collecting alignment constraints - bundle_use_gps:True bundle_use_gcp: True
# 2024-07-28 18:00:44,985 INFO: GCP constraints X (0) - Xp (0)
# 2024-07-28 18:00:44,986 INFO: GPS constraints X (0) - Xp (0)
# 2024-07-28 18:00:44,987 INFO: Collecting alignment constraints - bundle_use_gps:True bundle_use_gcp: True
# 2024-07-28 18:00:44,987 INFO: GCP constraints X (0) - Xp (0)
# 2024-07-28 18:00:44,987 INFO: GPS constraints X (0) - Xp (0)
# 2024-07-28 18:00:45,178 INFO: Triangulated: 1013
# 2024-07-28 18:00:45,386 INFO: Collecting alignment constraints - bundle_use_gps:True bundle_use_gcp: True
# 2024-07-28 18:00:45,386 INFO: GCP constraints X (0) - Xp (0)
# 2024-07-28 18:00:45,386 INFO: GPS constraints X (0) - Xp (0)
# 2024-07-28 18:00:45,387 INFO: Collecting alignment constraints - bundle_use_gps:True bundle_use_gcp: True
# 2024-07-28 18:00:45,387 INFO: GCP constraints X (0) - Xp (0)
# 2024-07-28 18:00:45,388 INFO: GPS constraints X (0) - Xp (0)
# 2024-07-28 18:00:45,523 INFO: Ran GLOBAL bundle in 0.12 secs.with 2/1013/2026 (2.00) shots/points/proj. (avg. length)
# 2024-07-28 18:00:45,523 DEBUG: Ceres Solver Report: Iterations: 22, Initial cost: 4.279334e+02, Final cost: 1.151878e+02, Termination: CONVERGENCE
# 2024-07-28 18:00:45,531 INFO: Removed outliers: 1
# 2024-07-28 18:00:45,547 INFO: -------------------------------------------------------
# 2024-07-28 18:00:45,562 INFO: kitchen02.jpg resection inliers: 598 / 700
# 2024-07-28 18:00:45,569 INFO: Adding kitchen02.jpg to the reconstruction
# 2024-07-28 18:00:45,707 INFO: Re-triangulating
# 2024-07-28 18:00:45,707 INFO: Collecting alignment constraints - bundle_use_gps:True bundle_use_gcp: True
# 2024-07-28 18:00:45,707 INFO: GCP constraints X (0) - Xp (0)
# 2024-07-28 18:00:45,708 INFO: GPS constraints X (0) - Xp (0)
# 2024-07-28 18:00:45,709 INFO: Collecting alignment constraints - bundle_use_gps:True bundle_use_gcp: True
# 2024-07-28 18:00:45,709 INFO: GCP constraints X (0) - Xp (0)
# 2024-07-28 18:00:45,709 INFO: GPS constraints X (0) - Xp (0)
# 2024-07-28 18:00:45,944 INFO: Ran GLOBAL bundle in 0.21 secs.with 3/1888/4514 (2.39) shots/points/proj. (avg. length)
# 2024-07-28 18:00:45,945 DEBUG: Ceres Solver Report: Iterations: 16, Initial cost: 9.917769e+02, Final cost: 3.001194e+02, Termination: CONVERGENCE
# 2024-07-28 18:00:46,427 INFO: Ran GLOBAL bundle in 0.20 secs.with 3/1602/4025 (2.51) shots/points/proj. (avg. length)
# 2024-07-28 18:00:46,428 DEBUG: Ceres Solver Report: Iterations: 16, Initial cost: 3.186874e+02, Final cost: 3.021584e+02, Termination: CONVERGENCE
# 2024-07-28 18:00:46,442 INFO: Removed outliers: 3
# 2024-07-28 18:00:46,442 INFO: Reconstruction now has 3 shots.
# 2024-07-28 18:00:46,444 INFO: -------------------------------------------------------
# 2024-07-28 18:00:46,460 INFO: kitchen07.jpg resection inliers: 541 / 694
# 2024-07-28 18:00:46,467 INFO: Adding kitchen07.jpg to the reconstruction
# 2024-07-28 18:00:46,560 INFO: Re-triangulating
# 2024-07-28 18:00:46,560 INFO: Collecting alignment constraints - bundle_use_gps:True bundle_use_gcp: True
# 2024-07-28 18:00:46,560 INFO: GCP constraints X (0) - Xp (0)
# 2024-07-28 18:00:46,560 INFO: GPS constraints X (0) - Xp (0)
# 2024-07-28 18:00:46,561 INFO: Collecting alignment constraints - bundle_use_gps:True bundle_use_gcp: True
# 2024-07-28 18:00:46,561 INFO: GCP constraints X (0) - Xp (0)
# 2024-07-28 18:00:46,562 INFO: GPS constraints X (0) - Xp (0)
# 2024-07-28 18:00:46,883 INFO: Ran GLOBAL bundle in 0.29 secs.with 4/2378/6300 (2.65) shots/points/proj. (avg. length)
# 2024-07-28 18:00:46,883 DEBUG: Ceres Solver Report: Iterations: 15, Initial cost: 9.063366e+02, Final cost: 6.590275e+02, Termination: CONVERGENCE
# 2024-07-28 18:00:47,563 INFO: Ran GLOBAL bundle in 0.31 secs.with 4/2633/6975 (2.65) shots/points/proj. (avg. length)
# 2024-07-28 18:00:47,564 DEBUG: Ceres Solver Report: Iterations: 14, Initial cost: 8.027584e+02, Final cost: 7.686493e+02, Termination: CONVERGENCE
# 2024-07-28 18:00:47,587 INFO: Removed outliers: 4
# 2024-07-28 18:00:47,588 INFO: Reconstruction now has 4 shots.
# 2024-07-28 18:00:47,591 INFO: -------------------------------------------------------
# 2024-07-28 18:00:47,601 INFO: kitchen05.jpg resection inliers: 198 / 290
# 2024-07-28 18:00:47,604 INFO: Adding kitchen05.jpg to the reconstruction
# 2024-07-28 18:00:47,805 INFO: Ran LOCAL bundle in 0.16 secs.with 5/2882/7758 (2.69) shots/points/proj. (avg. length)
# 2024-07-28 18:00:47,806 DEBUG: Ceres Solver Report: Iterations: 8, Initial cost: 8.934278e+02, Final cost: 7.976848e+02, Termination: CONVERGENCE
# 2024-07-28 18:00:47,830 INFO: Removed outliers: 0
# 2024-07-28 18:00:47,830 INFO: Reconstruction now has 5 shots.
# 2024-07-28 18:00:47,833 INFO: -------------------------------------------------------
# 2024-07-28 18:00:47,845 INFO: kitchen03.jpg resection inliers: 233 / 345
# 2024-07-28 18:00:47,848 INFO: Adding kitchen03.jpg to the reconstruction
# 2024-07-28 18:00:47,909 INFO: Re-triangulating
# 2024-07-28 18:00:47,910 INFO: Collecting alignment constraints - bundle_use_gps:True bundle_use_gcp: True
# 2024-07-28 18:00:47,910 INFO: GCP constraints X (0) - Xp (0)
# 2024-07-28 18:00:47,910 INFO: GPS constraints X (0) - Xp (0)
# 2024-07-28 18:00:47,911 INFO: Collecting alignment constraints - bundle_use_gps:True bundle_use_gcp: True
# 2024-07-28 18:00:47,911 INFO: GCP constraints X (0) - Xp (0)
# 2024-07-28 18:00:47,911 INFO: GPS constraints X (0) - Xp (0)
# 2024-07-28 18:00:48,699 INFO: Ran GLOBAL bundle in 0.75 secs.with 6/3445/9139 (2.65) shots/points/proj. (avg. length)
# 2024-07-28 18:00:48,699 DEBUG: Ceres Solver Report: Iterations: 28, Initial cost: 1.166436e+03, Final cost: 9.426055e+02, Termination: CONVERGENCE
# 2024-07-28 18:00:49,604 INFO: Ran GLOBAL bundle in 0.44 secs.with 6/3474/9390 (2.70) shots/points/proj. (avg. length)
# 2024-07-28 18:00:49,604 DEBUG: Ceres Solver Report: Iterations: 14, Initial cost: 1.130222e+03, Final cost: 1.061347e+03, Termination: CONVERGENCE
# 2024-07-28 18:00:49,635 INFO: Removed outliers: 2
# 2024-07-28 18:00:49,635 INFO: Reconstruction now has 6 shots.
# 2024-07-28 18:00:49,639 INFO: -------------------------------------------------------
# 2024-07-28 18:00:49,646 INFO: kitchen06.jpg resection inliers: 217 / 289
# 2024-07-28 18:00:49,649 INFO: Adding kitchen06.jpg to the reconstruction
# 2024-07-28 18:00:49,942 INFO: Ran LOCAL bundle in 0.26 secs.with 7/3749/10169 (2.71) shots/points/proj. (avg. length)
# 2024-07-28 18:00:49,942 DEBUG: Ceres Solver Report: Iterations: 11, Initial cost: 1.186858e+03, Final cost: 1.118265e+03, Termination: NO_CONVERGENCE
# 2024-07-28 18:00:49,975 INFO: Removed outliers: 5
# 2024-07-28 18:00:49,975 INFO: Reconstruction now has 7 shots.
# 2024-07-28 18:00:49,979 INFO: -------------------------------------------------------
# 2024-07-28 18:00:49,985 INFO: kitchen04.jpg resection inliers: 29 / 35
# 2024-07-28 18:00:49,986 INFO: Adding kitchen04.jpg to the reconstruction
# 2024-07-28 18:00:50,158 INFO: Ran LOCAL bundle in 0.15 secs.with 8/3784/10265 (2.71) shots/points/proj. (avg. length)
# 2024-07-28 18:00:50,158 DEBUG: Ceres Solver Report: Iterations: 5, Initial cost: 1.125234e+03, Final cost: 1.113308e+03, Termination: CONVERGENCE
# 2024-07-28 18:00:50,191 INFO: Removed outliers: 0
# 2024-07-28 18:00:50,192 INFO: Reconstruction now has 8 shots.
# 2024-07-28 18:00:50,195 INFO: -------------------------------------------------------
# 2024-07-28 18:00:50,204 INFO: kitchen12.jpg resection inliers: 27 / 43
# 2024-07-28 18:00:50,205 INFO: Adding kitchen12.jpg to the reconstruction
# 2024-07-28 18:00:50,458 INFO: Ran LOCAL bundle in 0.19 secs.with 9/4108/10942 (2.66) shots/points/proj. (avg. length)
# 2024-07-28 18:00:50,458 DEBUG: Ceres Solver Report: Iterations: 6, Initial cost: 1.159290e+03, Final cost: 1.137557e+03, Termination: CONVERGENCE
# 2024-07-28 18:00:50,493 INFO: Removed outliers: 0
# 2024-07-28 18:00:50,493 INFO: Reconstruction now has 9 shots.
# 2024-07-28 18:00:50,497 INFO: -------------------------------------------------------
# 2024-07-28 18:00:50,505 INFO: kitchen09.jpg resection inliers: 98 / 133
# 2024-07-28 18:00:50,507 INFO: Adding kitchen09.jpg to the reconstruction
# 2024-07-28 18:00:50,564 INFO: Re-triangulating
# 2024-07-28 18:00:50,564 INFO: Collecting alignment constraints - bundle_use_gps:True bundle_use_gcp: True
# 2024-07-28 18:00:50,564 INFO: GCP constraints X (0) - Xp (0)
# 2024-07-28 18:00:50,564 INFO: GPS constraints X (0) - Xp (0)
# 2024-07-28 18:00:50,566 INFO: Collecting alignment constraints - bundle_use_gps:True bundle_use_gcp: True
# 2024-07-28 18:00:50,566 INFO: GCP constraints X (0) - Xp (0)
# 2024-07-28 18:00:50,566 INFO: GPS constraints X (0) - Xp (0)
# 2024-07-28 18:00:51,276 INFO: Ran GLOBAL bundle in 0.66 secs.with 10/4507/11838 (2.63) shots/points/proj. (avg. length)
# 2024-07-28 18:00:51,276 DEBUG: Ceres Solver Report: Iterations: 17, Initial cost: 1.283809e+03, Final cost: 1.226814e+03, Termination: CONVERGENCE
# 2024-07-28 18:00:52,539 INFO: Ran GLOBAL bundle in 0.64 secs.with 10/4484/11904 (2.65) shots/points/proj. (avg. length)
# 2024-07-28 18:00:52,539 DEBUG: Ceres Solver Report: Iterations: 16, Initial cost: 1.386852e+03, Final cost: 1.317461e+03, Termination: CONVERGENCE
# 2024-07-28 18:00:52,580 INFO: Removed outliers: 5
# 2024-07-28 18:00:52,580 INFO: Reconstruction now has 10 shots.
# 2024-07-28 18:00:52,584 INFO: -------------------------------------------------------
# 2024-07-28 18:00:52,592 INFO: kitchen10.jpg resection inliers: 311 / 319
# 2024-07-28 18:00:52,596 INFO: Adding kitchen10.jpg to the reconstruction
# 2024-07-28 18:00:52,925 INFO: Ran LOCAL bundle in 0.26 secs.with 10/5164/13572 (2.63) shots/points/proj. (avg. length)
# 2024-07-28 18:00:52,925 DEBUG: Ceres Solver Report: Iterations: 7, Initial cost: 1.389736e+03, Final cost: 1.342840e+03, Termination: CONVERGENCE
# 2024-07-28 18:00:52,968 INFO: Removed outliers: 1
# 2024-07-28 18:00:52,969 INFO: Reconstruction now has 11 shots.
# 2024-07-28 18:00:52,973 INFO: -------------------------------------------------------
# 2024-07-28 18:00:52,981 INFO: kitchen11.jpg resection inliers: 273 / 291
# 2024-07-28 18:00:52,985 INFO: Adding kitchen11.jpg to the reconstruction
# 2024-07-28 18:00:53,072 INFO: Re-triangulating
# 2024-07-28 18:00:53,072 INFO: Collecting alignment constraints - bundle_use_gps:True bundle_use_gcp: True
# 2024-07-28 18:00:53,072 INFO: GCP constraints X (0) - Xp (0)
# 2024-07-28 18:00:53,072 INFO: GPS constraints X (0) - Xp (0)
# 2024-07-28 18:00:53,073 INFO: Collecting alignment constraints - bundle_use_gps:True bundle_use_gcp: True
# 2024-07-28 18:00:53,073 INFO: GCP constraints X (0) - Xp (0)
# 2024-07-28 18:00:53,074 INFO: GPS constraints X (0) - Xp (0)
# 2024-07-28 18:00:54,171 INFO: Ran GLOBAL bundle in 1.03 secs.with 12/6006/15532 (2.59) shots/points/proj. (avg. length)
# 2024-07-28 18:00:54,171 DEBUG: Ceres Solver Report: Iterations: 21, Initial cost: 1.610012e+03, Final cost: 1.493547e+03, Termination: CONVERGENCE
# 2024-07-28 18:00:55,742 INFO: Ran GLOBAL bundle in 0.81 secs.with 12/6001/15552 (2.59) shots/points/proj. (avg. length)
# 2024-07-28 18:00:55,742 DEBUG: Ceres Solver Report: Iterations: 14, Initial cost: 1.584387e+03, Final cost: 1.510310e+03, Termination: CONVERGENCE
# 2024-07-28 18:00:55,794 INFO: Removed outliers: 4
# 2024-07-28 18:00:55,794 INFO: Reconstruction now has 12 shots.
# 2024-07-28 18:00:55,798 INFO: -------------------------------------------------------
# 2024-07-28 18:00:55,799 INFO: Collecting alignment constraints - bundle_use_gps:True bundle_use_gcp: True
# 2024-07-28 18:00:55,799 INFO: GCP constraints X (0) - Xp (0)
# 2024-07-28 18:00:55,799 INFO: GPS constraints X (0) - Xp (0)
# 2024-07-28 18:00:55,800 INFO: Collecting alignment constraints - bundle_use_gps:True bundle_use_gcp: True
# 2024-07-28 18:00:55,800 INFO: GCP constraints X (0) - Xp (0)
# 2024-07-28 18:00:55,800 INFO: GPS constraints X (0) - Xp (0)
# 2024-07-28 18:00:56,850 INFO: Ran GLOBAL bundle in 0.98 secs.with 12/6001/15548 (2.59) shots/points/proj. (avg. length)
# 2024-07-28 18:00:56,850 DEBUG: Ceres Solver Report: Iterations: 20, Initial cost: 1.508306e+03, Final cost: 1.498697e+03, Termination: CONVERGENCE
# 2024-07-28 18:00:56,902 INFO: Removed outliers: 0
# 2024-07-28 18:00:56,975 INFO: Reconstruction 0: 12 images, 6001 points
# 2024-07-28 18:00:56,975 INFO: 1 partial reconstructions in total.

# %%
## RUN THIS CELL ONCE ONLY, you just need to create the Open3D environment once

## You need to select the "Open3D" environment before you run the next cells (top right corner to change kernel)
"""
# %%bash
# SWITCH to Open3D
source /opt/conda/bin/activate open3d
python -m ipykernel install --user --name open3d --display-name "Open3D"
"""
# Out:
# '\n%%bash\n# SWITCH to Open3D\nsource /opt/conda/bin/activate open3d\npython -m ipykernel install --user --name open3d --display-name "Open3D"\n'

# %%
def get_colors_from_ply(plyfile):
    '''
    Function to read the colors from a .ply file
    returns an RGB array scaled between [0,1]
    '''
    with open(plyfile, 'r') as f:
        colors = []
        columns = {}
        col_idx = 0
        header_done = False
        for line in f.readlines():
            if line.startswith('property'):
                columns[line.split()[-1]] = col_idx
                col_idx += 1
            if header_done:
                line_list = line.split()
                colors.append([float(line_list[columns['red']]),
                              float(line_list[columns['green']]),
                              float(line_list[columns['blue']])
                              ])
            if line.startswith('end_header'):
                header_done = True
        colors = np.array(colors)/255
    return colors

# %%
import open3d as o3d
import plotly
import plotly.graph_objects as go
import numpy as np
import plotly.graph_objects as go

#-------------------------------------------------------------------
#-------------------------------------------------------------------
#----------------------- Define your folder here -------------------
myfolder = "atef1"
#-------------------------------------------------------------------
#-------------------------------------------------------------------
# read point cloud data
pcd = o3d.io.read_point_cloud(myfolder + "/reconstruction.ply", format='ply')
# store the colors
pcd.colors = o3d.utility.Vector3dVector(get_colors_from_ply(myfolder + '/reconstruction.ply'))

# convert to array
points = np.asarray(pcd.points)
colors = np.asarray(pcd.colors)

fig = go.Figure(
    data=[
        go.Scatter3d(
            x=points[:,0], y=points[:,1], z=points[:,2], 
            mode='markers',
            marker=dict(size=5, color=colors)
        )
    ],
    layout=dict(
        scene=dict(
            xaxis=dict(visible=False),
            yaxis=dict(visible=False),
            zaxis=dict(visible=False)
        )
    )
)
fig.write_html('vis-sparse33.html')

# %% [markdown]
# OpenSfM has various functions to refine the 3d reconstruction.
# See https://opensfm.readthedocs.io/en/latest/using.html for more details.
#
# We will be using the `undistort` and `compute_depthmaps` functions to create a dense reconstruction of the scene

# %%
# %%bash
# source /opt/conda/bin/activate opensfm
# mamba install -y 'numpy>=1.19,<2.0.0'
# export PATH=$PATH:/opt/utils/OpenSfM/bin
#
# opensfm undistort atef1/
# opensfm compute_depthmaps atef1/
# Out:
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# Transaction
#
#   Prefix: /opt/conda/envs/opensfm
#
#   All requested packages already installed
#
#
# Looking for: ["numpy[version='>=1.19,<2.0.0']"]
#
#
# Pinned packages:
#   - python 3.10.*
# 2024-07-28 18:09:38,010 DEBUG: Undistorting the reconstruction
# 2024-07-28 18:09:38,335 INFO: Undistorting in parallel with 1 processes (141.09765625 MB per image)
# 2024-07-28 18:09:38,336 DEBUG: Undistorting image kitchen01.jpg
# 2024-07-28 18:09:40,487 DEBUG: Undistorting image kitchen10.jpg
# 2024-07-28 18:09:42,561 DEBUG: Undistorting image kitchen08.jpg
# 2024-07-28 18:09:44,594 DEBUG: Undistorting image kitchen09.jpg
# 2024-07-28 18:09:46,641 DEBUG: Undistorting image kitchen02.jpg
# 2024-07-28 18:09:48,788 DEBUG: Undistorting image kitchen07.jpg
# 2024-07-28 18:09:50,782 DEBUG: Undistorting image kitchen05.jpg
# 2024-07-28 18:09:52,773 DEBUG: Undistorting image kitchen03.jpg
# 2024-07-28 18:09:54,755 DEBUG: Undistorting image kitchen06.jpg
# 2024-07-28 18:09:56,738 DEBUG: Undistorting image kitchen04.jpg
# 2024-07-28 18:09:58,720 DEBUG: Undistorting image kitchen12.jpg
# 2024-07-28 18:10:00,768 DEBUG: Undistorting image kitchen11.jpg
# 2024-07-28 18:10:04,646 INFO: Computing neighbors
# 2024-07-28 18:10:05,215 INFO: Computing depthmap for image kitchen01.jpg with PATCH_MATCH_SAMPLE
# 2024-07-28 18:10:35,776 INFO: Computing depthmap for image kitchen10.jpg with PATCH_MATCH_SAMPLE
# 2024-07-28 18:11:05,012 INFO: Computing depthmap for image kitchen08.jpg with PATCH_MATCH_SAMPLE
# 2024-07-28 18:11:37,383 INFO: Computing depthmap for image kitchen09.jpg with PATCH_MATCH_SAMPLE
# 2024-07-28 18:12:09,343 INFO: Computing depthmap for image kitchen02.jpg with PATCH_MATCH_SAMPLE
# 2024-07-28 18:12:39,837 INFO: Computing depthmap for image kitchen07.jpg with PATCH_MATCH_SAMPLE
# 2024-07-28 18:13:11,223 INFO: Computing depthmap for image kitchen05.jpg with PATCH_MATCH_SAMPLE
# 2024-07-28 18:13:40,220 INFO: Computing depthmap for image kitchen03.jpg with PATCH_MATCH_SAMPLE
# 2024-07-28 18:14:09,793 INFO: Computing depthmap for image kitchen06.jpg with PATCH_MATCH_SAMPLE
# 2024-07-28 18:14:38,309 INFO: Computing depthmap for image kitchen04.jpg with PATCH_MATCH_SAMPLE
# 2024-07-28 18:15:07,287 INFO: Computing depthmap for image kitchen12.jpg with PATCH_MATCH_SAMPLE
# 2024-07-28 18:15:37,740 INFO: Computing depthmap for image kitchen11.jpg with PATCH_MATCH_SAMPLE
# 2024-07-28 18:16:08,106 INFO: Cleaning depthmap for image kitchen01.jpg
# 2024-07-28 18:16:08,806 INFO: Cleaning depthmap for image kitchen10.jpg
# 2024-07-28 18:16:09,467 INFO: Cleaning depthmap for image kitchen08.jpg
# 2024-07-28 18:16:10,244 INFO: Cleaning depthmap for image kitchen09.jpg
# 2024-07-28 18:16:10,908 INFO: Cleaning depthmap for image kitchen02.jpg
# 2024-07-28 18:16:11,641 INFO: Cleaning depthmap for image kitchen07.jpg
# 2024-07-28 18:16:12,390 INFO: Cleaning depthmap for image kitchen05.jpg
# 2024-07-28 18:16:13,083 INFO: Cleaning depthmap for image kitchen03.jpg
# 2024-07-28 18:16:13,775 INFO: Cleaning depthmap for image kitchen06.jpg
# 2024-07-28 18:16:14,445 INFO: Cleaning depthmap for image kitchen04.jpg
# 2024-07-28 18:16:14,996 INFO: Cleaning depthmap for image kitchen12.jpg
# 2024-07-28 18:16:15,625 INFO: Cleaning depthmap for image kitchen11.jpg
# 2024-07-28 18:16:16,233 INFO: Pruning depthmap for image kitchen01.jpg
# 2024-07-28 18:16:18,628 INFO: Pruning depthmap for image kitchen10.jpg
# 2024-07-28 18:16:20,630 INFO: Pruning depthmap for image kitchen08.jpg
# 2024-07-28 18:16:23,440 INFO: Pruning depthmap for image kitchen09.jpg
# 2024-07-28 18:16:25,493 INFO: Pruning depthmap for image kitchen02.jpg
# 2024-07-28 18:16:27,886 INFO: Pruning depthmap for image kitchen07.jpg
# 2024-07-28 18:16:30,886 INFO: Pruning depthmap for image kitchen05.jpg
# 2024-07-28 18:16:33,713 INFO: Pruning depthmap for image kitchen03.jpg
# 2024-07-28 18:16:36,744 INFO: Pruning depthmap for image kitchen06.jpg
# 2024-07-28 18:16:39,486 INFO: Pruning depthmap for image kitchen04.jpg
# 2024-07-28 18:16:41,452 INFO: Pruning depthmap for image kitchen12.jpg
# 2024-07-28 18:16:43,444 INFO: Pruning depthmap for image kitchen11.jpg
# 2024-07-28 18:16:45,422 INFO: Merging depthmaps

# %%
pcd_dense = o3d.io.read_point_cloud(myfolder + '/undistorted/depthmaps/merged.ply', format='ply')
pcd_dense.colors = o3d.utility.Vector3dVector(get_colors_from_ply(myfolder + "/undistorted/depthmaps/merged.ply"))
points_dense = np.asarray(pcd_dense.points)
colors_dense = np.asarray(pcd_dense.colors)

fig = go.Figure(
    data=[
        go.Scatter3d(
            x=points_dense[:,0], y=points_dense[:,1], z=points_dense[:,2], 
            mode='markers',
            marker=dict(size=1, color=colors_dense)
        )
    ],
    layout=dict(
        scene=dict(
            xaxis=dict(visible=False),
            yaxis=dict(visible=False),
            zaxis=dict(visible=False)
        )
    )
)
fig.write_html('vis-dense33.html')
